# %%
import sys
# !{sys.executable} -m pip install --user scikit-allel

# %%
import numpy as np
import scipy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_style('ticks')
sns.set_context('notebook')
import h5py
import allel; print('scikit-allel', allel.__version__)
# Out:
# scikit-allel 1.3.8

# %% [markdown]
# ## VCF to HDF5

# %%
allel.vcf_to_hdf5('/users/mcevoysu/scratch/output/Csativa/vcf_filtering/raw_SNP.vcf.gz', '/users/mcevoysu/scratch/output/Csativa/scikit-allel/raw_SNP.h5', fields='*')

# %% [markdown]
# ## Get data

# %%
callset_var_fn = '/users/mcevoysu/scratch/output/Csativa/scikit-allel/raw_SNP.h5'
callset_var = h5py.File(callset_var_fn, mode='r')

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
list(callset_var['variants'])
# Out:
# ['AC',
#  'AF',
#  'ALT',
#  'AN',
#  'BaseQRankSum',
#  'CHROM',
#  'DP',
#  'END',
#  'ExcessHet',
#  'FILTER_LowQual',
#  'FILTER_PASS',
#  'FS',
#  'ID',
#  'InbreedingCoeff',
#  'MLEAC',
#  'MLEAF',
#  'MQ',
#  'MQRankSum',
#  'POS',
#  'QD',
#  'QUAL',
#  'RAW_MQandDP',
#  'REF',
#  'ReadPosRankSum',
#  'SOR',
#  'altlen',
#  'is_snp',
#  'numalt']

# %% [markdown]
# ## Make datasets

# %%
variants = allel.VariantChunkedTable(callset_var['variants'])
variants
# Out:
# <VariantChunkedTable shape=(252785,) dtype=[('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')]
#    nbytes=43.2M cbytes=9.4M cratio=4.6
#    values=h5py._hl.group.Group>

# %%
variants_np = variants[:]
rawsnps = variants_np.query('(is_snp == True)')
rawsnps
# Out:
# <VariantTable shape=(170999,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([200,  -1,  -1], [0.317,   nan,   nan], [b'T', b'', b''], 630,    nan, b'Chr01',   353, -1,   0.    , False, False,  0.   , b'.',  0.3911, [625,  -1,  -1], [0.98 ,   nan,   nan], 60.  ,    nan,   368469, 25.36,  17926.6 , [-1, -1], b'C',    nan, 11.189, [0, 0, 0],  True, 1)
#  ([252,  -1,  -1], [0.39 ,   nan,   nan], [b'G', b'', b''], 644,    nan, b'Chr01',   472, -1,   0.    , False, False,  0.   , b'.',  0.4179, [630,  -1,  -1], [0.966,   nan,   nan], 60.  ,    nan,   368492, 28.73,  26211.8 , [-1, -1], b'T',    nan, 12.008, [0, 0, 0],  True, 1)
#  ([258,  -1,  -1], [0.398,   nan,   nan], [b'A', b'', b''], 646,    nan, b'Chr01',   514, -1,   0.    , False, False,  0.   , b'.',  0.4234, [636,  -1,  -1], [0.972,   nan,   nan], 60.  ,    nan,   368498, 30.97,  27822.8 , [-1, -1], b'T',    nan, 12.132, [0, 0, 0],  True, 1)
#  ...
#  ([307,  -1,  -1], [0.471,   nan,   nan], [b'T', b'', b''], 648,  0.   , b'Chr12',  6131, -1,   0.    , False, False,  0.   , b'.',  0.2284, [324,  -1,  -1], [0.494,   nan,   nan], 60.  ,  0.   , 49180333, 27.34, 102641.  , [-1, -1], b'C',  0.203,  1.104, [0, 0, 0],  True, 1)
#  ([ 31,  -1,  -1], [0.047,   nan,   nan], [b'A', b'', b''], 648, -0.971, b'Chr12', 13996, -1,   3.2612, False, False,  5.83 , b'.',  0.0044, [ 23,  -1,  -1], [0.035,   nan,   nan], 56.85, -6.038, 49180371,  0.59,    733.91, [-1, -1], b'G', -3.127,  0.277, [0, 0, 0],  True, 1)
#  ([200,  -1,  -1], [0.306,   nan,   nan], [b'A', b'', b''], 648, -2.953, b'Chr12', 18370, -1, 160.    , False, False, 22.307, b'.', -0.4427, [202,  -1,  -1], [0.308,   nan,   nan], 56.92, -5.375, 49180437,  6.78,  89767.1 , [-1, -1], b'T', -1.578,  0.133, [0, 0, 0],  True, 1)]

# %%
notsnp = variants_np.query('(is_snp != True)')
notsnp
# Out:
# <VariantTable shape=(81786,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([  2,  -1,  -1], [0.003049,      nan,      nan], [b'*', b'', b''], 648,   nan, b'Chr01', 16775, -1, 0.0067,  True, False,   0.   , b'.', 0.2416, [  2,  -1,  -1], [0.003049,      nan,      nan],   nan, nan,   368909, 0., 0., [-1, -1], b'T',    nan, 0.836, [-1,  0,  0], False, 1)
#  ([ 11,  -1,  -1], [0.017   ,      nan,      nan], [b'*', b'', b''], 648, 0.632, b'Chr01',  6277, -1, 0.3795,  True, False, 125.623, b'.', 0.1103, [ 10,  -1,  -1], [0.015   ,      nan,      nan], 60.  ,  0.,   492583, 0., 0., [-1, -1], b'T',  0.207, 4.503, [-1,  0,  0], False, 1)
#  ([ 11,  -1,  -1], [0.017   ,      nan,      nan], [b'*', b'', b''], 648,   nan, b'Chr01',  6254, -1, 0.3819,  True, False, 142.202, b'.', 0.1396, [ 10,  -1,  -1], [0.015   ,      nan,      nan],   nan, nan,   492584, 0., 0., [-1, -1], b'G',    nan, 5.889, [-1,  0,  0], False, 1)
#  ...
#  ([189,  -1,  -1], [0.291   ,      nan,      nan], [b'*', b'', b''], 648,   nan, b'Chr12',  5697, -1, 0.    ,  True, False,   0.   , b'.', 0.2673, [200,  -1,  -1], [0.305   ,      nan,      nan], 60.  ,  0., 49180318, 0., 0., [-1, -1], b'G', -0.164, 2.647, [-1,  0,  0], False, 1)
#  ([188,  -1,  -1], [0.29    ,      nan,      nan], [b'*', b'', b''], 648,   nan, b'Chr12',  5700, -1, 0.    ,  True, False,   0.   , b'.', 0.2703, [199,  -1,  -1], [0.303   ,      nan,      nan],   nan, nan, 49180319, 0., 0., [-1, -1], b'A',    nan, 2.663, [-1,  0,  0], False, 1)
#  ([188,  -1,  -1], [0.29    ,      nan,      nan], [b'*', b'', b''], 648, 0.14 , b'Chr12',  5698, -1, 0.    ,  True, False,   0.   , b'.', 0.2719, [199,  -1,  -1], [0.303   ,      nan,      nan], 59.92,  0., 49180320, 0., 0., [-1, -1], b'T',  0.168, 2.669, [-1,  0,  0], False, 1)]

# %% [markdown]
# ## Plot function

# %%
def plot_hist(f, dsubset='', bins=30, ):
    if dsubset == 'var':
        x = variants[f][:]
        l = 'Variant'
    elif dsubset == 'snp':
        x = rawsnps[f][:]
        l = 'Raw SNP'
    elif dsubset == 'notsnp':
        x = notsnp[f][:]
        l = 'Raw Not SNP'
    elif dsubset == 'biallelic':
        x = biallelic_np[f][:]
        l = 'Biallelic SNP'
    elif dsubset == 'varsel':
        x = var_selection[f][:]
        l = 'Filtered Variants'
    elif dsubset == 'snpsel':
        x = snp_selection[f][:]
        l = 'Filtered SNP'
    else:
        x = bi_selection[f][:]
        l = 'Biallelic SNP'
    fig, ax = plt.subplots(figsize=(10, 5))
    sns.despine(ax=ax, offset=10)
    ax.hist(x, bins=bins)
    ax.set_xlabel(f)
    ax.set_ylabel('No. variants')
    ax.set_title('%s %s distribution' % (l, f))

# %% [markdown]
# ## Find Biallelic SNPS

# %%
numalt = rawsnps['numalt']
np.max(numalt)
# Out:
# 3

# %%
count_numalt = np.bincount(numalt)
count_numalt
# Out:
# array([     0, 168261,   2690,     48])

# %%
n_multiallelic = np.sum(count_numalt[2:])
n_multiallelic
# Out:
# 2738

# %%
filter_expression = '(numalt == 1)'
biallelic_np = rawsnps.query(filter_expression)[:]
biallelic_np
# Out:
# <VariantTable shape=(168261,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([200,  -1,  -1], [0.317,   nan,   nan], [b'T', b'', b''], 630,    nan, b'Chr01',   353, -1,   0.    , False, False,  0.   , b'.',  0.3911, [625,  -1,  -1], [0.98 ,   nan,   nan], 60.  ,    nan,   368469, 25.36,  17926.6 , [-1, -1], b'C',    nan, 11.189, [0, 0, 0],  True, 1)
#  ([252,  -1,  -1], [0.39 ,   nan,   nan], [b'G', b'', b''], 644,    nan, b'Chr01',   472, -1,   0.    , False, False,  0.   , b'.',  0.4179, [630,  -1,  -1], [0.966,   nan,   nan], 60.  ,    nan,   368492, 28.73,  26211.8 , [-1, -1], b'T',    nan, 12.008, [0, 0, 0],  True, 1)
#  ([258,  -1,  -1], [0.398,   nan,   nan], [b'A', b'', b''], 646,    nan, b'Chr01',   514, -1,   0.    , False, False,  0.   , b'.',  0.4234, [636,  -1,  -1], [0.972,   nan,   nan], 60.  ,    nan,   368498, 30.97,  27822.8 , [-1, -1], b'T',    nan, 12.132, [0, 0, 0],  True, 1)
#  ...
#  ([307,  -1,  -1], [0.471,   nan,   nan], [b'T', b'', b''], 648,  0.   , b'Chr12',  6131, -1,   0.    , False, False,  0.   , b'.',  0.2284, [324,  -1,  -1], [0.494,   nan,   nan], 60.  ,  0.   , 49180333, 27.34, 102641.  , [-1, -1], b'C',  0.203,  1.104, [0, 0, 0],  True, 1)
#  ([ 31,  -1,  -1], [0.047,   nan,   nan], [b'A', b'', b''], 648, -0.971, b'Chr12', 13996, -1,   3.2612, False, False,  5.83 , b'.',  0.0044, [ 23,  -1,  -1], [0.035,   nan,   nan], 56.85, -6.038, 49180371,  0.59,    733.91, [-1, -1], b'G', -3.127,  0.277, [0, 0, 0],  True, 1)
#  ([200,  -1,  -1], [0.306,   nan,   nan], [b'A', b'', b''], 648, -2.953, b'Chr12', 18370, -1, 160.    , False, False, 22.307, b'.', -0.4427, [202,  -1,  -1], [0.308,   nan,   nan], 56.92, -5.375, 49180437,  6.78,  89767.1 , [-1, -1], b'T', -1.578,  0.133, [0, 0, 0],  True, 1)]

# %% [markdown]
# ## MQ - RMS mapping quality

# %%
plot_hist('MQ','var') # RMS mapping quality

# %%
plot_hist('MQ','biallelic') # RMS mapping quality

# %%
filter_expression = '(MQ < 55)'
bi_selection = biallelic_np.query(filter_expression)[:]
#np.count_nonzero(var_selection)

# %%
plot_hist('MQ')

# %%
filter_expression = '(MQ < 40)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('MQ')

# %%
plot_hist('MQ','notsnp')

# %% [markdown]
# ## QD - Variant Confidence/Quality by Depth

# %%
plot_hist('QD','var') # Variant Confidence/Quality by Depth

# %%
plot_hist('QD','biallelic') # Variant Confidence/Quality by Depth

# %%
filter_expression = '(QD < 2)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('QD')

# %%
plot_hist('QD','notsnp') # Variant Confidence/Quality by Depth

# %% [markdown]
# ## SOR - Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR', 'var') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR','biallelic') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
filter_expression = '(SOR > 3)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('SOR') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR','notsnp') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %% [markdown]
# ## MQRankSum - Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','var') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','biallelic') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
filter_expression = '(MQRankSum < -12.5)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('MQRankSum') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','notsnp') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %% [markdown]
# ## ReadPosRankSum - Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','var') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','biallelic') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','notsnp') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %% [markdown]
# ## DP - Approximate read depth

# %%
plot_hist('DP','var')

# %%
plot_hist('DP','biallelic')

# %%
filter_expression = '(DP > 20000) & (DP < 40000)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('DP')

# %%
plot_hist('DP','notsnp')

# %% [markdown]
# ## AN - Total number of alleles in called genotypes

# %%
plot_hist('AN','var') # Total number of alleles in called genotypes

# %%
plot_hist('AN','biallelic') # Total number of alleles in called genotypes

# %%
plot_hist('AN','notsnp') # Total number of alleles in called genotypes

# %% [markdown]
# ## Selected filter

# %%
# QD: Variant Confidence/Quality by Depth
# AN: Total number of alleles in called genotypes
filter_expression = '(QD >= 2) & (MQ >= 40) & (MQRankSum >= -12.5) & (is_snp)'
variant_selection = variants_np.eval(filter_expression)[:]
np.count_nonzero(variant_selection)
# Out:
# 132646

# %% [markdown]
# ## Genotype

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
genotypes_var = allel.GenotypeChunkedArray(calldata_var['GT'])
genotypes_var
# Out:
# <GenotypeChunkedArray shape=(252785, 324, 2) dtype=int8 chunks=(65536, 64, 2)
#    nbytes=156.2M cbytes=10.9M cratio=14.3
#    compression=gzip compression_opts=1
#    values=h5py._hl.dataset.Dataset>

# %%
# using the selected filters set above
gt_filtered_snps = genotypes_var.subset(variant_selection)
gt_filtered_snps
# Out:
# <GenotypeChunkedArray shape=(132646, 324, 2) dtype=int8 chunks=(2073, 324, 2)
#    nbytes=82.0M cbytes=11.7M cratio=7.0
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# grab the allele counts for the populations
ac = gt_filtered_snps.count_alleles()
ac
# Out:
# <AlleleCountsChunkedArray shape=(132646, 4) dtype=int32 chunks=(16581, 4)
#    nbytes=2.0M cbytes=479.2K cratio=4.3
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac[:]
# Out:
# <AlleleCountsArray shape=(132646, 4) dtype=int32>
# 644   4   0   0
# 261 385   0   0
# 430 218   0   0
# ...
# 645   3   0   0
# 341 307   0   0
# 448 200   0   0

# %%
# Which ones are biallelic?
is_biallelic_01 = ac.is_biallelic_01()[:]
ac1 = ac.compress(is_biallelic_01, axis=0)[:, :2]
ac1
##this part of the code is only for graphing the SFS, is not useful for filtering biallelic sites
# Out:
# array([[644,   4],
#        [261, 385],
#        [430, 218],
#        ...,
#        [645,   3],
#        [341, 307],
#        [448, 200]], dtype=int32)

# %%
# plot the sfs of the derived allele
s = allel.sfs_folded(ac1)
allel.plot_sfs(s, yscale="linear", n=ac1.sum(axis=1).max())
# Out:
# <Axes: xlabel='derived allele frequency', ylabel='site frequency'>

# %%
biallelic = (ac.max_allele() == 1)
###This is the filter expression for biallelic sites
biallelic
# Out:
# <ChunkedArrayWrapper shape=(132646,) dtype=bool chunks=(132646,)
#    nbytes=129.5K cbytes=11.3K cratio=11.4
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# select only the biallelic variants
gt_biallelic = gt_filtered_snps.compress(biallelic)
gt_biallelic
# Out:
# <GenotypeChunkedArray shape=(130246, 324, 2) dtype=int8 chunks=(2036, 324, 2)
#    nbytes=80.5M cbytes=11.3M cratio=7.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
n_variants = len(gt_biallelic)
n_variants
# Out:
# 130246

# %%
pc_missing = gt_biallelic.count_missing(axis=0)[:] * 100 / n_variants
pc_het = gt_biallelic.count_het(axis=0)[:] * 100 / n_variants

# %% [markdown]
# ## Samples

# %%
samples_var = callset_var['samples']
samples_var = list(samples_var)
samples_var
# Out:
# [b'AUT00079-001',
#  b'AUT00079-002',
#  b'AUT00079-003',
#  b'AUT00079-004',
#  b'AUT00079-005',
#  b'AUT00079-006',
#  b'AUT00079-007',
#  b'AUT00079-008',
#  b'AUT00079-009',
#  b'AUT00079-010',
#  b'AUT00079-011',
#  b'AUT00079-012',
#  b'AUT00079-013',
#  b'AUT00079-014',
#  b'AUT00079-015',
#  b'AUT00079-016',
#  b'AUT00079-017',
#  b'AUT00079-018',
#  b'AUT00079-019',
#  b'AUT00079-020',
#  b'AUT00079-021',
#  b'AUT00079-022',
#  b'AUT00079-023',
#  b'AUT00079-024',
#  b'AUT00079-025',
#  b'ESP00069-001',
#  b'ESP00069-002',
#  b'ESP00069-003',
#  b'ESP00069-004',
#  b'ESP00069-005',
#  b'ESP00069-006',
#  b'ESP00069-007',
#  b'ESP00069-008',
#  b'ESP00069-009',
#  b'ESP00069-010',
#  b'ESP00069-011',
#  b'ESP00069-012',
#  b'ESP00069-013',
#  b'ESP00069-014',
#  b'ESP00069-015',
#  b'ESP00069-016',
#  b'ESP00069-017',
#  b'ESP00069-018',
#  b'ESP00069-019',
#  b'ESP00069-020',
#  b'ESP00069-021',
#  b'ESP00069-022',
#  b'ESP00069-023',
#  b'ESP00069-024',
#  b'ESP00069-025',
#  b'ESP00087-001',
#  b'ESP00087-002',
#  b'ESP00087-003',
#  b'ESP00087-004',
#  b'ESP00087-005',
#  b'ESP00087-006',
#  b'ESP00087-007',
#  b'ESP00087-008',
#  b'ESP00087-009',
#  b'ESP00087-010',
#  b'ESP00087-011',
#  b'ESP00087-012',
#  b'ESP00087-013',
#  b'ESP00087-014',
#  b'ESP00087-015',
#  b'ESP00087-016',
#  b'ESP00087-017',
#  b'ESP00087-018',
#  b'ESP00087-019',
#  b'ESP00087-020',
#  b'ESP00087-021',
#  b'ESP00087-022',
#  b'ESP00087-023',
#  b'ESP00087-024',
#  b'ESP00287-001',
#  b'ESP00287-002',
#  b'ESP00287-003',
#  b'ESP00287-004',
#  b'ESP00287-005',
#  b'ESP00287-006',
#  b'ESP00287-007',
#  b'ESP00287-008',
#  b'ESP00287-009',
#  b'ESP00287-010',
#  b'ESP00287-011',
#  b'ESP00287-012',
#  b'ESP00287-013',
#  b'ESP00287-014',
#  b'ESP00287-015',
#  b'ESP00287-016',
#  b'ESP00287-017',
#  b'ESP00287-018',
#  b'ESP00287-019',
#  b'ESP00287-020',
#  b'ESP00287-021',
#  b'ESP00287-022',
#  b'ESP00287-023',
#  b'ESP00287-024',
#  b'ESP00287-025',
#  b'ESP00379-001',
#  b'ESP00379-002',
#  b'ESP00379-003',
#  b'ESP00379-004',
#  b'ESP00379-005',
#  b'ESP00379-006',
#  b'ESP00379-007',
#  b'ESP00379-008',
#  b'ESP00379-009',
#  b'ESP00379-010',
#  b'ESP00379-011',
#  b'ESP00379-012',
#  b'ESP00379-013',
#  b'ESP00379-014',
#  b'ESP00379-015',
#  b'ESP00379-016',
#  b'ESP00379-017',
#  b'ESP00379-018',
#  b'ESP00379-019',
#  b'ESP00379-020',
#  b'ESP00379-021',
#  b'ESP00379-022',
#  b'ESP00379-023',
#  b'ESP00379-024',
#  b'ESP00379-025',
#  b'ITA00274-001',
#  b'ITA00274-002',
#  b'ITA00274-003',
#  b'ITA00274-004',
#  b'ITA00274-005',
#  b'ITA00274-006',
#  b'ITA00274-007',
#  b'ITA00274-008',
#  b'ITA00274-009',
#  b'ITA00274-010',
#  b'ITA00274-011',
#  b'ITA00274-012',
#  b'ITA00274-013',
#  b'ITA00274-014',
#  b'ITA00274-015',
#  b'ITA00274-016',
#  b'ITA00274-017',
#  b'ITA00274-018',
#  b'ITA00274-019',
#  b'ITA00274-020',
#  b'ITA00274-021',
#  b'ITA00274-022',
#  b'ITA00274-023',
#  b'ITA00274-024',
#  b'ITA00274-025',
#  b'ROU00146-001',
#  b'ROU00146-002',
#  b'ROU00146-003',
#  b'ROU00146-004',
#  b'ROU00146-005',
#  b'ROU00146-006',
#  b'ROU00146-007',
#  b'ROU00146-008',
#  b'ROU00146-009',
#  b'ROU00146-010',
#  b'ROU00146-011',
#  b'ROU00146-012',
#  b'ROU00146-013',
#  b'ROU00146-014',
#  b'ROU00146-015',
#  b'ROU00146-016',
#  b'ROU00146-017',
#  b'ROU00146-018',
#  b'ROU00146-019',
#  b'ROU00146-020',
#  b'ROU00146-021',
#  b'ROU00146-022',
#  b'ROU00146-023',
#  b'ROU00146-024',
#  b'ROU00146-025',
#  b'TUR00057-001',
#  b'TUR00057-002',
#  b'TUR00057-003',
#  b'TUR00057-004',
#  b'TUR00057-005',
#  b'TUR00057-006',
#  b'TUR00057-007',
#  b'TUR00057-008',
#  b'TUR00057-009',
#  b'TUR00057-010',
#  b'TUR00057-011',
#  b'TUR00057-012',
#  b'TUR00057-013',
#  b'TUR00057-014',
#  b'TUR00057-015',
#  b'TUR00057-016',
#  b'TUR00057-017',
#  b'TUR00057-018',
#  b'TUR00057-019',
#  b'TUR00057-020',
#  b'TUR00057-021',
#  b'TUR00057-022',
#  b'TUR00057-023',
#  b'TUR00057-024',
#  b'TUR00057-025',
#  b'TUR00075-001',
#  b'TUR00075-002',
#  b'TUR00075-003',
#  b'TUR00075-004',
#  b'TUR00075-005',
#  b'TUR00075-006',
#  b'TUR00075-007',
#  b'TUR00075-008',
#  b'TUR00075-009',
#  b'TUR00075-010',
#  b'TUR00075-011',
#  b'TUR00075-012',
#  b'TUR00075-013',
#  b'TUR00075-014',
#  b'TUR00075-015',
#  b'TUR00075-016',
#  b'TUR00075-017',
#  b'TUR00075-018',
#  b'TUR00075-019',
#  b'TUR00075-020',
#  b'TUR00075-021',
#  b'TUR00075-022',
#  b'TUR00075-023',
#  b'TUR00075-024',
#  b'TUR00075-025',
#  b'TUR00100-001',
#  b'TUR00100-002',
#  b'TUR00100-003',
#  b'TUR00100-004',
#  b'TUR00100-005',
#  b'TUR00100-006',
#  b'TUR00100-007',
#  b'TUR00100-008',
#  b'TUR00100-009',
#  b'TUR00100-010',
#  b'TUR00100-011',
#  b'TUR00100-012',
#  b'TUR00100-013',
#  b'TUR00100-014',
#  b'TUR00100-015',
#  b'TUR00100-016',
#  b'TUR00100-017',
#  b'TUR00100-018',
#  b'TUR00100-019',
#  b'TUR00100-020',
#  b'TUR00100-021',
#  b'TUR00100-022',
#  b'TUR00100-023',
#  b'TUR00100-024',
#  b'TUR00100-025',
#  b'TUR00125-001',
#  b'TUR00125-002',
#  b'TUR00125-003',
#  b'TUR00125-004',
#  b'TUR00125-005',
#  b'TUR00125-006',
#  b'TUR00125-007',
#  b'TUR00125-008',
#  b'TUR00125-009',
#  b'TUR00125-010',
#  b'TUR00125-011',
#  b'TUR00125-012',
#  b'TUR00125-013',
#  b'TUR00125-014',
#  b'TUR00125-015',
#  b'TUR00125-016',
#  b'TUR00125-017',
#  b'TUR00125-018',
#  b'TUR00125-019',
#  b'TUR00125-020',
#  b'TUR00125-021',
#  b'TUR00125-022',
#  b'TUR00125-023',
#  b'TUR00125-024',
#  b'TUR00125-025',
#  b'TUR00218-001',
#  b'TUR00218-002',
#  b'TUR00218-003',
#  b'TUR00218-004',
#  b'TUR00218-005',
#  b'TUR00218-006',
#  b'TUR00218-007',
#  b'TUR00218-008',
#  b'TUR00218-009',
#  b'TUR00218-010',
#  b'TUR00218-011',
#  b'TUR00218-012',
#  b'TUR00218-013',
#  b'TUR00218-014',
#  b'TUR00218-015',
#  b'TUR00218-016',
#  b'TUR00218-017',
#  b'TUR00218-018',
#  b'TUR00218-019',
#  b'TUR00218-020',
#  b'TUR00218-021',
#  b'TUR00218-022',
#  b'TUR00218-023',
#  b'TUR00218-024',
#  b'TUR00218-025',
#  b'TUR00258-001',
#  b'TUR00258-002',
#  b'TUR00258-003',
#  b'TUR00258-004',
#  b'TUR00258-005',
#  b'TUR00258-006',
#  b'TUR00258-007',
#  b'TUR00258-008',
#  b'TUR00258-009',
#  b'TUR00258-010',
#  b'TUR00258-011',
#  b'TUR00258-012',
#  b'TUR00258-013',
#  b'TUR00258-014',
#  b'TUR00258-015',
#  b'TUR00258-016',
#  b'TUR00258-017',
#  b'TUR00258-018',
#  b'TUR00258-019',
#  b'TUR00258-020',
#  b'TUR00258-021',
#  b'TUR00258-022',
#  b'TUR00258-023',
#  b'TUR00258-024',
#  b'TUR00258-025']

# %%
samples_fn = '~/scratch/data/Csativa/Castanea_sativa_list_scikit-allel.txt'
samples = pandas.read_csv(samples_fn, sep='\t')
samples
# Out:
#                ID Population
# 0    AUT00079-001   AUT00079
# 1    AUT00079-002   AUT00079
# 2    AUT00079-003   AUT00079
# 3    AUT00079-004   AUT00079
# 4    AUT00079-005   AUT00079
# ..            ...        ...
# 319  TUR00258-021   TUR00258
# 320  TUR00258-022   TUR00258
# 321  TUR00258-023   TUR00258
# 322  TUR00258-024   TUR00258
# 323  TUR00258-025   TUR00258
#
# [324 rows x 2 columns]

# %%
samples.Population.value_counts()
# Out:
# Population
# AUT00079    25
# ESP00069    25
# ESP00287    25
# ESP00379    25
# ITA00274    25
# TUR00100    25
# ROU00146    25
# TUR00057    25
# TUR00075    25
# TUR00218    25
# TUR00125    25
# TUR00258    25
# ESP00087    24
# Name: count, dtype: int64

# %%
populations = samples.Population.unique()
populations
###This identifiers come from the metadata file
# Out:
# array(['AUT00079', 'ESP00069', 'ESP00087', 'ESP00287', 'ESP00379',
#        'ITA00274', 'ROU00146', 'TUR00057', 'TUR00075', 'TUR00100',
#        'TUR00125', 'TUR00218', 'TUR00258'], dtype=object)

# %% [markdown]
# ## Gt frequency function

# %%
def plot_genotype_frequency(pc, title):
    fig, ax = plt.subplots(figsize=(24, 5))
    sns.despine(ax=ax, offset=24)
    left = np.arange(len(pc))
    palette = sns.color_palette("hls", 13)
    pop2color = {'AUT00079': palette[0],
                 'ESP00069': palette[7],
                 'ESP00087': palette[1],
                 'ESP00287': palette[8],
                 'ESP00379': palette[2],
                 'ITA00274': palette[9],
                 'ROU00146': palette[3],
                 'TUR00057': palette[10],
                 'TUR00075': palette[4],
                 'TUR00100': palette[11],
                 'TUR00125': palette[5],
                 'TUR00218': palette[12],
                 'TUR00258': palette[6]}
    colors = [pop2color[p] for p in samples.Population]
    ax.bar(left, pc, color=colors)
    ax.set_xlim(0, len(pc))
    ax.set_xlabel('Sample index')
    ax.set_ylabel('Percent calls')
    ax.set_title(title)
    handles = [mpl.patches.Patch(color=palette[0]),
               mpl.patches.Patch(color=palette[7]),
               mpl.patches.Patch(color=palette[1]),
               mpl.patches.Patch(color=palette[8]),
               mpl.patches.Patch(color=palette[2]),
               mpl.patches.Patch(color=palette[9]),
               mpl.patches.Patch(color=palette[3]),
               mpl.patches.Patch(color=palette[10]),
               mpl.patches.Patch(color=palette[4]),
               mpl.patches.Patch(color=palette[11]),
               mpl.patches.Patch(color=palette[5]),
               mpl.patches.Patch(color=palette[12]),
               mpl.patches.Patch(color=palette[6])]
    ax.legend(handles=handles, labels=['AUT00079', 'ESP00069', 'ESP00087', 'ESP00287', 'ESP00379',
       'ITA00274', 'ROU00146', 'TUR00057', 'TUR00075', 'TUR00100',
       'TUR00125', 'TUR00218', 'TUR00258'], title='Population',
              bbox_to_anchor=(1, 1), loc='upper left')

# %% [markdown]
# ## Plot missing

# %%
plot_genotype_frequency(pc_missing, 'Missing')

# %% [markdown]
# ## Plot heterozygosity

# %%
plot_genotype_frequency(pc_het, 'Heterozygosity')

# %% [markdown]
# ## PCA

# %%
palette = sns.color_palette("hls",13)
pop_colours = {    
                'AUT00079': palette[0],
                 'ESP00069': palette[7],
                 'ESP00087': palette[1],
                 'ESP00287': palette[8],
                 'ESP00379': palette[2],
                 'ITA00274': palette[9],
                 'ROU00146': palette[3],
                 'TUR00057': palette[10],
                 'TUR00075': palette[4],
                 'TUR00100': palette[11],
                 'TUR00125': palette[5],
                 'TUR00218': palette[12],
                 'TUR00258': palette[6]
}

# %%
def plot_pca_coords(coords, model, pc1, pc2, ax, sample_population):
    sns.despine(ax=ax, offset=5)
    x = coords[:, pc1]
    y = coords[:, pc2]
    for pop in populations:
        flt = (sample_population == pop)
        ax.plot(x[flt], y[flt], marker='o', linestyle=' ', color=pop_colours[pop], 
                label=pop, markersize=6, mec='k', mew=.5)
    ax.set_xlabel('PC%s (%.1f%%)' % (pc1+1, model.explained_variance_ratio_[pc1]*100))
    ax.set_ylabel('PC%s (%.1f%%)' % (pc2+1, model.explained_variance_ratio_[pc2]*100))
    

def fig_pca(coords, model, title, sample_population=None):
    if sample_population is None:
        sample_population = samples.Population
    # plot coords for PCs 1 vs 2, 3 vs 4
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 2, 1)
    plot_pca_coords(coords, model, 0, 1, ax, sample_population)
    ax = fig.add_subplot(1, 2, 2)
    plot_pca_coords(coords, model, 2, 3, ax, sample_population)
    ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
    fig.suptitle(title, y=1.02)
    fig.tight_layout()

# %%
ac2 = gt_biallelic.count_alleles()
ac2
# Out:
# <AlleleCountsChunkedArray shape=(130246, 2) dtype=int32 chunks=(32562, 2)
#    nbytes=1017.5K cbytes=357.6K cratio=2.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
flt = (ac2[:, :2].min(axis=1) > 1)
gf = gt_biallelic.compress(flt, axis=0)
gn = gf.to_n_alt()
gn
# Out:
# <ChunkedArrayWrapper shape=(106658, 324) dtype=int8 chunks=(3334, 324)
#    nbytes=33.0M cbytes=7.2M cratio=4.6
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
coords1, model1 = allel.pca(gn, n_components=10, scaler='patterson')

# %%
fig_pca(coords1, model1, 'Figure 1. Conventional PCA.')

# %%
outliers = coords1[:,0]>1000
samples[outliers]
# Out:
#                ID Population
# 114  ESP00379-016   ESP00379
