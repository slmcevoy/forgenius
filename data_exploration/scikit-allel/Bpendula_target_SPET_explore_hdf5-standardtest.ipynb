# %%
import sys
# !{sys.executable} -m pip install --user scikit-allel

# %%
import numpy as np
import scipy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_style('ticks')
sns.set_context('notebook')
import h5py
import allel; print('scikit-allel', allel.__version__)
# Out:
# scikit-allel 1.3.8

# %% [markdown]
# ## VCF to HDF5

# %%
#allel.vcf_to_hdf5('/users/mcevoysu/scratch/output/Bpendula/vcf_filtering/raw_SNP_target.vcf.gz', '/users/mcevoysu/scratch/output/Bpendula/scikit-allel/raw_SNP_target.h5', fields='*')

# %% [markdown]
# ## Get data

# %%
callset_var_fn = '/users/mcevoysu/scratch/output/Bpendula/scikit-allel/raw_SNP_target.h5'
callset_var = h5py.File(callset_var_fn, mode='r')

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
list(callset_var['variants'])
# Out:
# ['AC',
#  'AF',
#  'ALT',
#  'AN',
#  'BaseQRankSum',
#  'CHROM',
#  'DP',
#  'END',
#  'ExcessHet',
#  'FILTER_FILT',
#  'FILTER_LowQual',
#  'FILTER_PASS',
#  'FS',
#  'ID',
#  'InbreedingCoeff',
#  'MLEAC',
#  'MLEAF',
#  'MQ',
#  'MQRankSum',
#  'POS',
#  'QD',
#  'QUAL',
#  'RAW_MQandDP',
#  'REF',
#  'ReadPosRankSum',
#  'SOR',
#  'altlen',
#  'is_snp',
#  'numalt']

# %% [markdown]
# ## Make datasets

# %%
variants = allel.VariantChunkedTable(callset_var['variants'])
variants
# Out:
# <VariantChunkedTable shape=(291588,) dtype=[('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')]
#    nbytes=49.8M cbytes=11.2M cratio=4.4
#    values=h5py._hl.group.Group>

# %%
variants_np = variants[:]
rawsnps = variants_np.query('(is_snp == True)')
rawsnps
# Out:
# <VariantTable shape=(193510,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([ 7, -1, -1], [0.009459,      nan,      nan], [b'A', b'', b''], 728, 0.341, b'Contig0', 22410, -1, 0.1243, False, False, 0.   , b'.', -0.0097, [ 6, -1, -1], [0.008108,      nan,      nan], 60., 0., 169179, 13.71, 3495.82, [-1, -1], b'G',  0.7  , 0.65 , [0, 0, 0],  True, 1)
#  ([12, -1, -1], [0.016   ,      nan,      nan], [b'C', b'', b''], 728, 0.901, b'Contig0', 22417, -1, 0.3935, False, False, 1.764, b'.', -0.0171, [12, -1, -1], [0.016   ,      nan,      nan], 60., 0., 169188, 14.4 , 9043.64, [-1, -1], b'T',  0.519, 0.915, [0, 0, 0],  True, 1)
#  ([ 9, 13, -1], [0.012   , 0.019   ,      nan], [b'A', b'C', b''], 728, 0.579, b'Contig0', 22386, -1, 1.5316, False, False, 2.172, b'.', -0.0322, [ 9, 14, -1], [0.012   , 0.019   ,      nan], 60., 0., 169189,  5.9 , 5760.59, [-1, -1], b'G',  0.612, 0.982, [0, 0, 0],  True, 2)
#  ...
#  ([ 5, -1, -1], [0.006757,      nan,      nan], [b'T', b'', b''], 728, 0.   , b'Contig996',  9468, -1, 0.0592, False, False, 0.   , b'.', -0.0149, [ 5, -1, -1], [0.006757,      nan,      nan], 60., 0., 252412, 13.56,  962.66, [-1, -1], b'C', -1.016, 0.519, [0, 0, 0],  True, 1)
#  ([ 2, -1, -1], [0.002703,      nan,      nan], [b'C', b'', b''], 728, 2.2  , b'Contig996',  7460, -1, 0.0059, False, False, 0.   , b'.', -0.0161, [ 2, -1, -1], [0.002703,      nan,      nan], 60., 0., 252447, 16.08,  691.38, [-1, -1], b'T',  1.63 , 0.65 , [0, 0, 0],  True, 1)
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'A', b'', b''], 728, 0.   , b'Contig996',  7095, -1, 0.    , False, False, 0.   , b'.',  0.0304, [ 1, -1, -1], [0.001351,      nan,      nan], 60., 0., 252452,  4.23,   33.83, [-1, -1], b'G',  0.319, 0.169, [0, 0, 0],  True, 1)]

# %%
notsnp = variants_np.query('(is_snp != True)')
notsnp
# Out:
# <VariantTable shape=(98078,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([ 8, -1, -1], [0.012   ,      nan,      nan], [b'*', b'', b''], 728,    nan, b'Contig0', 22354, -1, 0.2137,  True, False, 0., b'.', -0.0124, [ 8, -1, -1], [0.011   ,      nan,      nan], nan, nan, 169201, 0., 0., [-1, -1], b'A',  nan, 0.669, [-1,  0,  0], False, 1)
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'*', b'', b''], 728, -1.184, b'Contig0',  8524, -1, 0.    ,  True, False, 0., b'.',  0.025 , [ 1, -1, -1], [0.001351,      nan,      nan], 60.,  0., 169364, 0., 0., [-1, -1], b'C', 0.21, 0.03 , [-1,  0,  0], False, 1)
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'*', b'', b''], 728,    nan, b'Contig0',  8509, -1, 0.    ,  True, False, 0., b'.', -0.0158, [ 1, -1, -1], [0.001351,      nan,      nan], nan, nan, 169365, 0., 0., [-1, -1], b'A',  nan, 0.132, [-1,  0,  0], False, 1)
#  ...
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'*', b'', b''], 728,    nan, b'Contig996',  2878, -1, 0.    ,  True, False, 0., b'.',  0.1426, [ 1, -1, -1], [0.001351,      nan,      nan], nan, nan, 252542, 0., 0., [-1, -1], b'A',  nan, 0.446, [-1,  0,  0], False, 1)
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'*', b'', b''], 728,    nan, b'Contig996',  2861, -1, 0.    ,  True, False, 0., b'.',  0.1376, [ 1, -1, -1], [0.001351,      nan,      nan], nan, nan, 252543, 0., 0., [-1, -1], b'G',  nan, 0.446, [-1,  0,  0], False, 1)
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'*', b'', b''], 728,    nan, b'Contig996',  2854, -1, 0.    ,  True, False, 0., b'.',  0.1413, [ 1, -1, -1], [0.001351,      nan,      nan], nan, nan, 252544, 0., 0., [-1, -1], b'A',  nan, 0.446, [-1,  0,  0], False, 1)]

# %% [markdown]
# ## Plot function

# %%
def plot_hist(f, dsubset='', bins=30, ):
    if dsubset == 'var':
        x = variants[f][:]
        l = 'Variant'
    elif dsubset == 'snp':
        x = rawsnps[f][:]
        l = 'Raw SNP'
    elif dsubset == 'notsnp':
        x = notsnp[f][:]
        l = 'Raw Not SNP'
    elif dsubset == 'biallelic':
        x = biallelic_np[f][:]
        l = 'Biallelic SNP'
    elif dsubset == 'varsel':
        x = var_selection[f][:]
        l = 'Filtered Variants'
    elif dsubset == 'snpsel':
        x = snp_selection[f][:]
        l = 'Filtered SNP'
    else:
        x = bi_selection[f][:]
        l = 'Biallelic SNP'
    fig, ax = plt.subplots(figsize=(10, 5))
    sns.despine(ax=ax, offset=10)
    ax.hist(x, bins=bins)
    ax.set_xlabel(f)
    ax.set_ylabel('No. variants')
    ax.set_title('%s %s distribution' % (l, f))

# %% [markdown]
# ## Find Biallelic SNPS

# %%
numalt = rawsnps['numalt']
np.max(numalt)
# Out:
# 1

# %%
count_numalt = np.bincount(numalt)
count_numalt
# Out:
# array([    0, 91089])

# %%
n_multiallelic = np.sum(count_numalt[2:])
n_multiallelic
# Out:
# 0

# %%
filter_expression = '(numalt == 1)'
biallelic_np = rawsnps.query(filter_expression)[:]
biallelic_np
# Out:
# <VariantTable shape=(91089,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_FILT', '?'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([ 6, -1, -1], [0.009459,      nan,      nan], [b'A', b'', b''], 722, 0.341, b'Contig0', 22410, -1, 0.1243, False, False,  True, 0.   , b'.', -0.0097, [ 6, -1, -1], [0.008108,      nan,      nan], 60., 0., 169179, 13.71, 3495.82, [-1, -1], b'G',  0.7  , 0.65 , [0, 0, 0],  True, 1)
#  ([12, -1, -1], [0.016   ,      nan,      nan], [b'C', b'', b''], 720, 0.901, b'Contig0', 22417, -1, 0.3935, False, False,  True, 1.764, b'.', -0.0171, [12, -1, -1], [0.016   ,      nan,      nan], 60., 0., 169188, 14.4 , 9043.64, [-1, -1], b'T',  0.519, 0.915, [0, 0, 0],  True, 1)
#  ([ 5, -1, -1], [0.006757,      nan,      nan], [b'C', b'', b''], 726, 0.017, b'Contig0', 22389, -1, 0.059 , False, False,  True, 4.856, b'.', -0.0069, [ 5, -1, -1], [0.006757,      nan,      nan], 60., 0., 169204, 12.59, 2480.44, [-1, -1], b'A', -0.183, 0.409, [0, 0, 0],  True, 1)
#  ...
#  ([ 1, -1, -1], [0.001351,      nan,      nan], [b'G', b'', b''], 700, 0.747, b'Contig996', 12845, -1, 0.    , False, False,  True, 0.   , b'.', -0.006 , [ 1, -1, -1], [0.001351,      nan,      nan], 60., 0., 252333,  3.67,   84.46, [-1, -1], b'T',  0.041, 0.061, [0, 0, 0],  True, 1)
#  ([ 4, -1, -1], [0.006757,      nan,      nan], [b'T', b'', b''], 660, 0.   , b'Contig996',  9468, -1, 0.0592, False, False,  True, 0.   , b'.', -0.0149, [ 5, -1, -1], [0.006757,      nan,      nan], 60., 0., 252412, 13.56,  962.66, [-1, -1], b'C', -1.016, 0.519, [0, 0, 0],  True, 1)
#  ([ 2, -1, -1], [0.002703,      nan,      nan], [b'C', b'', b''], 598, 2.2  , b'Contig996',  7460, -1, 0.0059, False, False,  True, 0.   , b'.', -0.0161, [ 2, -1, -1], [0.002703,      nan,      nan], 60., 0., 252447, 16.08,  691.38, [-1, -1], b'T',  1.63 , 0.65 , [0, 0, 0],  True, 1)]

# %% [markdown]
# ## MQ - RMS mapping quality

# %%
plot_hist('MQ','var') # RMS mapping quality

# %%
plot_hist('MQ','biallelic') # RMS mapping quality

# %%
filter_expression = '(MQ < 55)'
bi_selection = biallelic_np.query(filter_expression)[:]
#np.count_nonzero(var_selection)

# %%
plot_hist('MQ')

# %%
filter_expression = '(MQ < 40)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('MQ')

# %%
plot_hist('MQ','notsnp')

# %% [markdown]
# ## QD - Variant Confidence/Quality by Depth

# %%
plot_hist('QD','var') # Variant Confidence/Quality by Depth

# %%
plot_hist('QD','biallelic') # Variant Confidence/Quality by Depth

# %%
filter_expression = '(QD < 2)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('QD')

# %%
plot_hist('QD','notsnp') # Variant Confidence/Quality by Depth

# %% [markdown]
# ## SOR - Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR', 'var') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR','biallelic') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
filter_expression = '(SOR > 3)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('SOR') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR','notsnp') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %% [markdown]
# ## MQRankSum - Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','var') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','biallelic') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
filter_expression = '(MQRankSum < -12.5)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('MQRankSum') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','notsnp') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %% [markdown]
# ## ReadPosRankSum - Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','var') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','biallelic') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','notsnp') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %% [markdown]
# ## DP - Approximate read depth

# %%
plot_hist('DP','var')

# %%
plot_hist('DP','biallelic')

# %%
filter_expression = '(DP > 20000) & (DP < 40000)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('DP')

# %%
plot_hist('DP','notsnp')

# %% [markdown]
# ## AN - Total number of alleles in called genotypes

# %%
plot_hist('AN','var') # Total number of alleles in called genotypes

# %%
plot_hist('AN','biallelic') # Total number of alleles in called genotypes

# %%
plot_hist('AN','notsnp') # Total number of alleles in called genotypes

# %% [markdown]
# ## Selected filter

# %%
# QD: Variant Confidence/Quality by Depth
# AN: Total number of alleles in called genotypes
filter_expression = '(QD >= 2) & (MQ >= 40) & (MQRankSum >= -12.5) & (is_snp)'
variant_selection = variants_np.eval(filter_expression)[:]
np.count_nonzero(variant_selection)
# Out:
# 173835

# %% [markdown]
# ## Genotype

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
genotypes_var = allel.GenotypeChunkedArray(calldata_var['GT'])
genotypes_var
# Out:
# <GenotypeChunkedArray shape=(291588, 364, 2) dtype=int8 chunks=(65536, 64, 2)
#    nbytes=202.4M cbytes=8.7M cratio=23.2
#    compression=gzip compression_opts=1
#    values=h5py._hl.dataset.Dataset>

# %%
# using the selected filters set above
gt_filtered_snps = genotypes_var.subset(variant_selection)
gt_filtered_snps
# Out:
# <GenotypeChunkedArray shape=(173835, 364, 2) dtype=int8 chunks=(1359, 364, 2)
#    nbytes=120.7M cbytes=8.7M cratio=13.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# grab the allele counts for the populations
ac = gt_filtered_snps.count_alleles()
ac
# Out:
# <AlleleCountsChunkedArray shape=(173835, 4) dtype=int32 chunks=(21730, 4)
#    nbytes=2.7M cbytes=386.4K cratio=7.0
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac[:]
# Out:
# <AlleleCountsArray shape=(173835, 4) dtype=int32>
# 721   7   0   0
# 716  12   0   0
# 706   9  13   0
# ...
# 723   5   0   0
# 726   2   0   0
# 727   1   0   0

# %%
# Which ones are biallelic?
is_biallelic_01 = ac.is_biallelic_01()[:]
ac1 = ac.compress(is_biallelic_01, axis=0)[:, :2]
ac1
##this part of the code is only for graphing the SFS, is not useful for filtering biallelic sites
# Out:
# array([[721,   7],
#        [716,  12],
#        [723,   5],
#        ...,
#        [723,   5],
#        [726,   2],
#        [727,   1]], dtype=int32)

# %%
# plot the sfs of the derived allele
s = allel.sfs_folded(ac1)
allel.plot_sfs(s, yscale="linear", n=ac1.sum(axis=1).max())
# Out:
# <Axes: xlabel='derived allele frequency', ylabel='site frequency'>

# %%
biallelic = (ac.max_allele() == 1)
###This is the filter expression for biallelic sites
biallelic
# Out:
# <ChunkedArrayWrapper shape=(173835,) dtype=bool chunks=(173835,)
#    nbytes=169.8K cbytes=32.3K cratio=5.3
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# select only the biallelic variants
gt_biallelic = gt_filtered_snps.compress(biallelic)
gt_biallelic
# Out:
# <GenotypeChunkedArray shape=(165044, 364, 2) dtype=int8 chunks=(1290, 364, 2)
#    nbytes=114.6M cbytes=8.0M cratio=14.4
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
n_variants = len(gt_biallelic)
n_variants
# Out:
# 165044

# %%
pc_missing = gt_biallelic.count_missing(axis=0)[:] * 100 / n_variants
pc_het = gt_biallelic.count_het(axis=0)[:] * 100 / n_variants

# %%
pc_missing
# Out:
# array([0.02544776, 0.03211265, 0.03877754, 0.03090085, 0.03150675,
#        0.03574804, 0.04059524, 0.04423063, 0.02847725, 0.03150675,
#        0.02665956, 0.03271855, 0.02665956, 0.02726546, 0.02302416,
#        0.02181237, 0.04665423, 0.03332445, 0.03393035, 0.03332445,
#        0.02544776, 0.03150675, 0.02181237, 0.02605366, 0.02302416,
#        0.02484186, 0.03029495, 0.03029495, 0.02787136, 0.02665956,
#        0.02968905, 0.02120647, 0.02665956, 0.02968905, 0.02908315,
#        0.03029495, 0.02908315, 0.02968905, 0.02726546, 0.02665956,
#        0.03029495, 0.02060057, 0.03514214, 0.02423596, 0.04544243,
#        0.02363006, 0.03332445, 0.01938877, 0.03877754, 0.02605366,
#        0.01635927, 0.01938877, 0.01393568, 0.02241826, 0.01393568,
#        0.01635927, 0.01393568, 0.01030028, 0.01272388, 0.01635927,
#        0.01757107, 0.01817697, 0.01151208, 0.01938877, 0.01575337,
#        0.01575337, 0.01817697, 0.01696517, 0.01211798, 0.01514748,
#        0.02120647, 0.01878287, 0.01332978, 0.01878287, 0.01514748,
#        0.01696517, 0.02363006, 0.01211798, 0.01090618, 0.01878287,
#        0.01514748, 0.01393568, 0.02241826, 0.03090085, 0.01272388,
#        0.01393568, 0.04362473, 0.02120647, 0.04665423, 0.01635927,
#        0.02363006, 0.01575337, 0.01575337, 0.02181237, 0.01696517,
#        0.01332978, 0.01514748, 0.01211798, 0.01454158, 0.02302416,
#        0.01696517, 0.00969438, 0.02241826, 0.01878287, 0.03877754,
#        0.01332978, 0.01332978, 0.01454158, 0.01938877, 0.02605366,
#        0.02363006, 0.01151208, 0.01454158, 0.01938877, 0.03938344,
#        0.01878287, 0.01817697, 0.01332978, 0.01514748, 0.01514748,
#        0.01635927, 0.02241826, 0.01151208, 0.01817697, 0.01575337,
#        0.01332978, 0.01696517, 0.01151208, 0.02605366, 0.02605366,
#        0.01332978, 0.01575337, 0.02241826, 0.01454158, 0.01514748,
#        0.02181237, 0.02665956, 0.01575337, 0.04968372, 0.02665956,
#        0.01938877, 0.02665956, 0.01999467, 0.01393568, 0.01999467,
#        0.01332978, 0.01211798, 0.02363006, 0.02120647, 0.01999467,
#        0.01151208, 0.01696517, 0.01635927, 0.02363006, 0.01272388,
#        0.01454158, 0.00545309, 0.02060057, 0.00787669, 0.0024236 ,
#        0.01635927, 0.01211798, 0.02181237, 0.00484719, 0.00787669,
#        0.0024236 , 0.01757107, 0.00605899, 0.01393568, 0.01211798,
#        0.02968905, 0.0030295 , 0.00484719, 0.02363006, 0.01757107,
#        0.02363006, 0.02302416, 0.01696517, 0.02423596, 0.01030028,
#        0.02484186, 0.02484186, 0.02120647, 0.01393568, 0.02423596,
#        0.01272388, 0.00848259, 0.01696517, 0.01696517, 0.01878287,
#        0.01696517, 0.01817697, 0.02423596, 0.01757107, 0.01514748,
#        0.01514748, 0.01817697, 0.01393568, 0.01696517, 0.01938877,
#        0.01575337, 0.01211798, 0.00908849, 0.01454158, 0.01938877,
#        0.01332978, 0.01454158, 0.02423596, 0.01514748, 0.01635927,
#        0.01090618, 0.01030028, 0.01999467, 0.01635927, 0.01817697,
#        0.01878287, 0.01030028, 0.02726546, 0.00666489, 0.01332978,
#        0.01272388, 0.03574804, 0.02060057, 0.02665956, 0.02544776,
#        0.02363006, 0.02181237, 0.01454158, 0.01090618, 0.02363006,
#        0.02120647, 0.02787136, 0.02363006, 0.03695984, 0.02302416,
#        0.03514214, 0.01211798, 0.01575337, 0.01817697, 0.03514214,
#        0.03695984, 0.00666489, 0.00484719, 0.00666489, 0.0018177 ,
#        0.00363539, 0.00424129, 0.00605899, 0.01757107, 0.0024236 ,
#        0.00363539, 0.00484719, 0.00545309, 0.00363539, 0.01151208,
#        0.0024236 , 0.00363539, 0.00666489, 0.00969438, 0.01151208,
#        0.00969438, 0.01272388, 0.0030295 , 0.01272388, 0.00484719,
#        0.00545309, 0.01514748, 0.02484186, 0.01272388, 0.01030028,
#        0.01696517, 0.01272388, 0.02423596, 0.00969438, 0.02120647,
#        0.01757107, 0.00848259, 0.01030028, 0.01332978, 0.01090618,
#        0.01151208, 0.01030028, 0.01635927, 0.01030028, 0.01090618,
#        0.01635927, 0.01514748, 0.01514748, 0.01211798, 0.01635927,
#        0.02726546, 0.02120647, 0.02241826, 0.03271855, 0.01696517,
#        0.02363006, 0.01757107, 0.01272388, 0.01393568, 0.01999467,
#        0.01454158, 0.01635927, 0.02302416, 0.01817697, 0.02302416,
#        0.01332978, 0.02241826, 0.01272388, 0.01817697, 0.01454158,
#        0.01938877, 0.01817697, 0.01938877, 0.01817697, 0.00666489,
#        0.01999467, 0.01151208, 0.00666489, 0.01030028, 0.04907782,
#        0.01090618, 0.01817697, 0.00484719, 0.00545309, 0.01393568,
#        0.02908315, 0.01332978, 0.00605899, 0.00545309, 0.00969438,
#        0.00484719, 0.01030028, 0.01090618, 0.01938877, 0.01635927,
#        0.02060057, 0.01272388, 0.01332978, 0.01999467, 0.01454158,
#        0.00848259, 0.00787669, 0.01878287, 0.00424129, 0.01999467,
#        0.0006059 , 0.02665956, 0.01696517, 0.01575337, 0.01938877,
#        0.02787136, 0.01817697, 0.01151208, 0.01454158, 0.04665423,
#        0.02423596, 0.01272388, 0.01090618, 0.02181237, 0.00969438,
#        0.03271855, 0.00424129, 0.00484719, 0.02181237])

# %% [markdown]
# ## Samples

# %%
samples_var = callset_var['samples']
samples_var = list(samples_var)
samples_var
# Out:
# [b'ESP00102-001',
#  b'ESP00102-002',
#  b'ESP00102-003',
#  b'ESP00102-004',
#  b'ESP00102-005',
#  b'ESP00102-006',
#  b'ESP00102-007',
#  b'ESP00102-008',
#  b'ESP00102-009',
#  b'ESP00102-010',
#  b'ESP00102-011',
#  b'ESP00102-012',
#  b'ESP00102-013',
#  b'ESP00102-014',
#  b'ESP00102-015',
#  b'ESP00102-016',
#  b'ESP00102-017',
#  b'ESP00102-018',
#  b'ESP00102-019',
#  b'ESP00102-020',
#  b'ESP00102-021',
#  b'ESP00102-022',
#  b'ESP00102-023',
#  b'ESP00102-024',
#  b'ESP00102-025',
#  b'ESP00199-001',
#  b'ESP00199-002',
#  b'ESP00199-003',
#  b'ESP00199-004',
#  b'ESP00199-005',
#  b'ESP00199-006',
#  b'ESP00199-007',
#  b'ESP00199-008',
#  b'ESP00199-009',
#  b'ESP00199-010',
#  b'ESP00199-011',
#  b'ESP00199-012',
#  b'ESP00199-013',
#  b'ESP00199-014',
#  b'ESP00199-015',
#  b'ESP00199-016',
#  b'ESP00199-017',
#  b'ESP00199-018',
#  b'ESP00199-019',
#  b'ESP00199-020',
#  b'ESP00199-021',
#  b'ESP00199-022',
#  b'ESP00199-023',
#  b'ESP00199-024',
#  b'ESP00199-025',
#  b'ESP00337-001',
#  b'ESP00337-002',
#  b'ESP00337-003',
#  b'ESP00337-004',
#  b'ESP00337-005',
#  b'ESP00337-006',
#  b'ESP00337-007',
#  b'ESP00337-008',
#  b'ESP00337-009',
#  b'ESP00337-010',
#  b'ESP00337-011',
#  b'ESP00337-012',
#  b'ESP00337-013',
#  b'ESP00337-014',
#  b'ESP00337-015',
#  b'ESP00337-016',
#  b'ESP00337-017',
#  b'ESP00337-018',
#  b'ESP00337-019',
#  b'ESP00337-020',
#  b'ESP00337-021',
#  b'ESP00337-022',
#  b'ESP00337-023',
#  b'ESP00337-024',
#  b'ESP00337-025',
#  b'FIN00015-001',
#  b'FIN00015-002',
#  b'FIN00015-003',
#  b'FIN00015-004',
#  b'FIN00015-005',
#  b'FIN00015-006',
#  b'FIN00015-007',
#  b'FIN00015-008',
#  b'FIN00015-009',
#  b'FIN00015-010',
#  b'FIN00015-011',
#  b'FIN00015-012',
#  b'FIN00015-013',
#  b'FIN00015-014',
#  b'FIN00015-015',
#  b'FIN00015-016',
#  b'FIN00015-017',
#  b'FIN00015-018',
#  b'FIN00015-019',
#  b'FIN00015-020',
#  b'FIN00015-021',
#  b'FIN00015-022',
#  b'FIN00015-023',
#  b'FIN00015-024',
#  b'FIN00015-025',
#  b'FIN00020-001',
#  b'FIN00020-002',
#  b'FIN00020-003',
#  b'FIN00020-004',
#  b'FIN00020-005',
#  b'FIN00020-006',
#  b'FIN00020-007',
#  b'FIN00020-008',
#  b'FIN00020-009',
#  b'FIN00020-010',
#  b'FIN00020-011',
#  b'FIN00020-012',
#  b'FIN00020-013',
#  b'FIN00020-014',
#  b'FIN00020-015',
#  b'FIN00020-016',
#  b'FIN00020-017',
#  b'FIN00020-018',
#  b'FIN00020-019',
#  b'FIN00020-020',
#  b'FIN00020-021',
#  b'FIN00020-022',
#  b'FIN00020-023',
#  b'FIN00020-024',
#  b'FIN00020-025',
#  b'FIN00044-001',
#  b'FIN00044-002',
#  b'FIN00044-003',
#  b'FIN00044-004',
#  b'FIN00044-005',
#  b'FIN00044-006',
#  b'FIN00044-007',
#  b'FIN00044-009',
#  b'FIN00044-010',
#  b'FIN00044-011',
#  b'FIN00044-012',
#  b'FIN00044-013',
#  b'FIN00044-014',
#  b'FIN00044-015',
#  b'FIN00044-016',
#  b'FIN00044-017',
#  b'FIN00044-018',
#  b'FIN00044-019',
#  b'FIN00044-020',
#  b'FIN00044-021',
#  b'FIN00044-022',
#  b'FIN00044-023',
#  b'FIN00044-024',
#  b'FIN00044-025',
#  b'FIN00046-001',
#  b'FIN00046-002',
#  b'FIN00046-003',
#  b'FIN00046-004',
#  b'FIN00046-005',
#  b'FIN00046-006',
#  b'FIN00046-007',
#  b'FIN00046-008',
#  b'FIN00046-009',
#  b'FIN00046-010',
#  b'FIN00046-011',
#  b'FIN00046-012',
#  b'FIN00046-013',
#  b'FIN00046-014',
#  b'FIN00046-015',
#  b'FIN00046-016',
#  b'FIN00046-017',
#  b'FIN00046-018',
#  b'FIN00046-019',
#  b'FIN00046-020',
#  b'FIN00046-021',
#  b'FIN00046-022',
#  b'FIN00046-023',
#  b'FIN00046-024',
#  b'FIN00046-025',
#  b'GBR00013-001',
#  b'GBR00013-002',
#  b'GBR00013-003',
#  b'GBR00013-004',
#  b'GBR00013-005',
#  b'GBR00013-006',
#  b'GBR00013-007',
#  b'GBR00013-008',
#  b'GBR00013-009',
#  b'GBR00013-010',
#  b'GBR00013-013',
#  b'GBR00013-014',
#  b'GBR00013-015',
#  b'GBR00013-016',
#  b'GBR00013-017',
#  b'GBR00013-018',
#  b'GBR00013-019',
#  b'GBR00013-020',
#  b'GBR00013-021',
#  b'GBR00013-022',
#  b'GBR00013-023',
#  b'GBR00013-024',
#  b'GBR00013-025',
#  b'GBR00015-101',
#  b'GBR00015-102',
#  b'GBR00015-103',
#  b'GBR00015-104',
#  b'GBR00015-105',
#  b'GBR00015-106',
#  b'GBR00015-107',
#  b'GBR00015-108',
#  b'GBR00015-109',
#  b'GBR00015-110',
#  b'GBR00015-111',
#  b'GBR00015-112',
#  b'GBR00015-113',
#  b'GBR00015-114',
#  b'GBR00015-115',
#  b'GBR00015-116',
#  b'GBR00015-117',
#  b'GBR00015-118',
#  b'GBR00015-119',
#  b'GBR00015-120',
#  b'GBR00015-121',
#  b'GBR00015-122',
#  b'GBR00015-123',
#  b'GBR00015-124',
#  b'IRL00017-001',
#  b'IRL00017-002',
#  b'IRL00017-003',
#  b'IRL00017-004',
#  b'IRL00017-005',
#  b'IRL00017-006',
#  b'IRL00017-007',
#  b'IRL00017-008',
#  b'IRL00017-009',
#  b'IRL00017-010',
#  b'IRL00017-011',
#  b'IRL00017-012',
#  b'IRL00017-013',
#  b'IRL00017-014',
#  b'IRL00017-015',
#  b'IRL00017-016',
#  b'IRL00017-017',
#  b'IRL00017-018',
#  b'IRL00017-019',
#  b'IRL00017-020',
#  b'ITA00243-001',
#  b'ITA00243-002',
#  b'ITA00243-003',
#  b'ITA00243-004',
#  b'ITA00243-005',
#  b'ITA00243-006',
#  b'ITA00243-007',
#  b'ITA00243-008',
#  b'ITA00243-009',
#  b'ITA00243-010',
#  b'ITA00243-011',
#  b'ITA00243-012',
#  b'ITA00243-013',
#  b'ITA00243-014',
#  b'ITA00243-015',
#  b'ITA00243-016',
#  b'ITA00243-017',
#  b'ITA00243-018',
#  b'ITA00243-019',
#  b'ITA00243-020',
#  b'ITA00243-021',
#  b'ITA00243-022',
#  b'ITA00243-023',
#  b'ITA00243-024',
#  b'ITA00243-025',
#  b'ITA00248-001',
#  b'ITA00248-002',
#  b'ITA00248-003',
#  b'ITA00248-004',
#  b'ITA00248-005',
#  b'ITA00248-006',
#  b'ITA00248-007',
#  b'ITA00248-009',
#  b'ITA00248-010',
#  b'ITA00248-011',
#  b'ITA00248-012',
#  b'ITA00248-013',
#  b'ITA00248-014',
#  b'ITA00248-015',
#  b'ITA00248-017',
#  b'ITA00248-018',
#  b'ITA00248-019',
#  b'ITA00248-020',
#  b'ITA00248-021',
#  b'ITA00248-022',
#  b'ITA00248-023',
#  b'ITA00248-024',
#  b'ITA00248-025',
#  b'LUX00021-001',
#  b'LUX00021-002',
#  b'LUX00021-003',
#  b'LUX00021-004',
#  b'LUX00021-005',
#  b'LUX00021-006',
#  b'LUX00021-007',
#  b'LUX00021-008',
#  b'LUX00021-009',
#  b'LUX00021-010',
#  b'LUX00021-011',
#  b'LUX00021-012',
#  b'LUX00021-013',
#  b'LUX00021-014',
#  b'LUX00021-015',
#  b'LUX00021-016',
#  b'LUX00021-017',
#  b'LUX00021-018',
#  b'LUX00021-019',
#  b'LUX00021-020',
#  b'LUX00021-021',
#  b'LUX00021-022',
#  b'LUX00021-023',
#  b'LUX00021-024',
#  b'LUX00021-025',
#  b'NLD00013-001',
#  b'NLD00013-002',
#  b'NLD00013-003',
#  b'NLD00013-004',
#  b'NLD00013-005',
#  b'NLD00013-006',
#  b'NLD00013-007',
#  b'NLD00013-008',
#  b'NLD00013-009',
#  b'NLD00013-010',
#  b'NLD00013-011',
#  b'NLD00013-012',
#  b'NLD00013-013',
#  b'NLD00013-014',
#  b'NLD00013-015',
#  b'NLD00013-016',
#  b'NLD00013-017',
#  b'NLD00013-018',
#  b'NLD00013-019',
#  b'NLD00013-020',
#  b'NLD00013-021',
#  b'NLD00013-022',
#  b'NLD00013-023',
#  b'NLD00013-024',
#  b'NLD00013-025',
#  b'SWE00093-001',
#  b'SWE00093-002',
#  b'SWE00093-003',
#  b'SWE00093-004',
#  b'SWE00093-005',
#  b'SWE00093-006',
#  b'SWE00093-007',
#  b'SWE00093-008',
#  b'SWE00093-009',
#  b'SWE00093-010',
#  b'SWE00093-011',
#  b'SWE00093-012',
#  b'SWE00093-013',
#  b'SWE00093-014',
#  b'SWE00093-015',
#  b'SWE00093-016',
#  b'SWE00093-017',
#  b'SWE00093-018',
#  b'SWE00093-019',
#  b'SWE00093-020',
#  b'SWE00093-021',
#  b'SWE00093-022',
#  b'SWE00093-023',
#  b'SWE00093-024',
#  b'SWE00093-025']

# %%
samples_fn = '~/scratch/data/Bpendula/Betula_pendula_sample_list_scikit-allel.txt'
samples = pandas.read_csv(samples_fn, sep='\t')
samples
# Out:
#                ID Population
# 0    ESP00102-001   ESP00102
# 1    ESP00102-002   ESP00102
# 2    ESP00102-003   ESP00102
# 3    ESP00102-004   ESP00102
# 4    ESP00102-005   ESP00102
# ..            ...        ...
# 359  SWE00093-021   SWE00093
# 360  SWE00093-022   SWE00093
# 361  SWE00093-023   SWE00093
# 362  SWE00093-024   SWE00093
# 363  SWE00093-025   SWE00093
#
# [364 rows x 2 columns]

# %%
samples.Population.value_counts()
# Out:
# Population
# ESP00102    25
# ESP00199    25
# ESP00337    25
# FIN00015    25
# FIN00020    25
# FIN00046    25
# ITA00243    25
# NLD00013    25
# SWE00093    25
# LUX00021    25
# FIN00044    24
# GBR00015    24
# GBR00013    23
# ITA00248    23
# IRL00017    20
# Name: count, dtype: int64

# %%
populations = samples.Population.unique()
populations
###This identifiers come from the metadata file
# Out:
# array(['ESP00102', 'ESP00199', 'ESP00337', 'FIN00015', 'FIN00020',
#        'FIN00044', 'FIN00046', 'GBR00013', 'GBR00015', 'IRL00017',
#        'ITA00243', 'ITA00248', 'LUX00021', 'NLD00013', 'SWE00093'],
#       dtype=object)

# %% [markdown]
# ## Gt frequency function

# %%
def plot_genotype_frequency(pc, title):
    fig, ax = plt.subplots(figsize=(24, 5))
    sns.despine(ax=ax, offset=24)
    left = np.arange(len(pc))
    palette = sns.color_palette("hls", 15)
    pop2color = {'ESP00102': palette[0],
                 'ESP00199': palette[8],
                 'ESP00337': palette[1],
                 'FIN00015': palette[9],
                 'FIN00020': palette[2],
                 'FIN00044': palette[10],
                 'FIN00046': palette[3],
                 'GBR00013': palette[11],
                 'GBR00015': palette[4],
                 'IRL00017': palette[12],
                 'ITA00243': palette[5],
                 'ITA00248': palette[13],
                 'LUX00021': palette[6],
                 'NLD00013': palette[14],
                 'SWE00093': palette[7]}
    colors = [pop2color[p] for p in samples.Population]
    ax.bar(left, pc, color=colors)
    ax.set_xlim(0, len(pc))
    ax.set_xlabel('Sample index')
    ax.set_ylabel('Percent calls')
    ax.set_title(title)
    handles = [mpl.patches.Patch(color=palette[0]),
               mpl.patches.Patch(color=palette[8]),
               mpl.patches.Patch(color=palette[1]),
               mpl.patches.Patch(color=palette[9]),
               mpl.patches.Patch(color=palette[2]),
               mpl.patches.Patch(color=palette[10]),
               mpl.patches.Patch(color=palette[3]),
               mpl.patches.Patch(color=palette[11]),
               mpl.patches.Patch(color=palette[4]),
               mpl.patches.Patch(color=palette[12]),
               mpl.patches.Patch(color=palette[5]),
               mpl.patches.Patch(color=palette[13]),
               mpl.patches.Patch(color=palette[6]),
               mpl.patches.Patch(color=palette[14]),
               mpl.patches.Patch(color=palette[7])]
    ax.legend(handles=handles, labels=['ESP00102', 'ESP00199', 'ESP00337', 'FIN00015', 'FIN00020',
       'FIN00044', 'FIN00046', 'GBR00013', 'GBR00015', 'IRL00017',
       'ITA00243', 'ITA00248', 'LUX00021', 'NLD00013', 'SWE00093'], title='Population',
              bbox_to_anchor=(1, 1), loc='upper left')

# %% [markdown]
# ## Plot missing

# %%
plot_genotype_frequency(pc_missing, 'Missing')

# %% [markdown]
# ## Plot heterozygosity

# %%
plot_genotype_frequency(pc_het, 'Heterozygosity')

# %% [markdown]
# ## PCA

# %%
palette = sns.color_palette("hls",15)
pop_colours = {    
                'ESP00102': palette[0],
                 'ESP00199': palette[8],
                 'ESP00337': palette[1],
                 'FIN00015': palette[9],
                 'FIN00020': palette[2],
                 'FIN00044': palette[10],
                 'FIN00046': palette[3],
                 'GBR00013': palette[11],
                 'GBR00015': palette[4],
                 'IRL00017': palette[12],
                 'ITA00243': palette[5],
                 'ITA00248': palette[13],
                 'LUX00021': palette[6],
                 'NLD00013': palette[14],
                 'SWE00093': palette[7]
}

# %%
def plot_pca_coords(coords, model, pc1, pc2, ax, sample_population):
    sns.despine(ax=ax, offset=5)
    x = coords[:, pc1]
    y = coords[:, pc2]
    for pop in populations:
        flt = (sample_population == pop)
        ax.plot(x[flt], y[flt], marker='o', linestyle=' ', color=pop_colours[pop], 
                label=pop, markersize=6, mec='k', mew=.5)
    ax.set_xlabel('PC%s (%.1f%%)' % (pc1+1, model.explained_variance_ratio_[pc1]*100))
    ax.set_ylabel('PC%s (%.1f%%)' % (pc2+1, model.explained_variance_ratio_[pc2]*100))
    

def fig_pca(coords, model, title, sample_population=None):
    if sample_population is None:
        sample_population = samples.Population
    # plot coords for PCs 1 vs 2, 3 vs 4
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 2, 1)
    plot_pca_coords(coords, model, 0, 1, ax, sample_population)
    ax = fig.add_subplot(1, 2, 2)
    plot_pca_coords(coords, model, 2, 3, ax, sample_population)
    ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
    fig.suptitle(title, y=1.02)
    fig.tight_layout()

# %%
ac2 = gt_biallelic.count_alleles()
ac2
# Out:
# <AlleleCountsChunkedArray shape=(165044, 2) dtype=int32 chunks=(41261, 2)
#    nbytes=1.3M cbytes=299.2K cratio=4.3
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
flt = (ac2[:, :2].min(axis=1) > 1)
gf = gt_biallelic.compress(flt, axis=0)
gn = gf.to_n_alt()
gn

# %%
coords1, model1 = allel.pca(gn, n_components=10, scaler='patterson')

# %%
fig_pca(coords1, model1, 'Figure 1. Conventional PCA.')

# %%
outliers = coords1[:,2]>200
samples[outliers]
# Out:
#               ID Population
# 86  FIN00015-012   FIN00015
# 88  FIN00015-014   FIN00015

# %%
coords1[:,0]
# Out:
# array([-148.96736  , -197.95537  , -198.57387  , -201.8657   ,
#        -165.3257   , -184.72801  , -187.34471  , -189.30516  ,
#        -197.34256  , -215.09433  , -200.77628  , -134.40858  ,
#        -200.45107  , -196.02504  , -183.73141  , -193.42851  ,
#        -167.54001  , -184.20921  , -192.22644  , -177.55489  ,
#          46.86318  , -164.9474   , -195.9502   , -203.5213   ,
#        -209.70267  , -123.563416 , -141.0141   , -107.05087  ,
#        -125.844154 , -130.56828  , -208.34506  , -213.80334  ,
#        -151.85046  , -182.63112  , -189.61328  , -214.39732  ,
#        -192.13258  , -202.48477  , -181.60262  , -203.55826  ,
#        -172.12856  , -208.17152  , -188.02425  , -203.78363  ,
#        -180.83885  , -249.29147  , -183.55765  , -224.52124  ,
#        -133.97878  , -187.82428  ,   43.688126 ,   46.331024 ,
#          47.796894 ,   44.143612 ,   52.169872 ,   48.611168 ,
#          45.684795 ,   47.777916 ,   49.965984 ,   38.025356 ,
#          46.953    ,   43.407917 ,   44.516014 ,   48.488895 ,
#          41.447933 ,   44.572636 ,   46.966583 ,   48.531555 ,
#          50.716198 ,   52.815197 ,   42.291386 ,   49.818    ,
#          47.94245  ,   37.080643 ,   49.974796 ,   56.926323 ,
#           1.0678477,   47.54793  ,   42.603596 ,   46.005974 ,
#          47.282166 ,   48.632122 ,   54.73994  ,   50.87147  ,
#          52.07381  ,   57.14947  , -271.5426   ,   52.92377  ,
#        -260.9875   ,   50.133785 ,   52.308502 ,   55.487206 ,
#          48.113213 ,   53.873272 ,   56.269825 ,   57.28665  ,
#          51.5773   ,   55.62724  ,   46.674744 ,   59.46208  ,
#          62.274387 ,   54.227715 ,   44.98157  ,   52.00338  ,
#        -173.70782  ,   47.388145 ,   57.86156  ,   55.80584  ,
#          56.309372 ,   56.848213 ,   60.04094  ,   54.136284 ,
#          52.27322  ,   55.972275 , -175.54582  ,   50.83804  ,
#          55.098198 ,   49.480087 ,   56.18848  ,   52.137447 ,
#          48.08431  ,   56.76294  ,   54.79556  ,   51.5113   ,
#          50.45768  ,   55.164974 ,   48.56765  ,   48.598133 ,
#          54.56271  ,   48.992756 ,   53.49611  ,   54.244656 ,
#          52.073986 ,   52.164932 ,   56.60433  ,   49.438225 ,
#          45.02032  ,   55.32405  , -139.88503  ,   52.428112 ,
#          51.044556 ,   59.817635 ,   57.8514   ,   49.649395 ,
#          45.685165 ,   58.4193   ,   55.626747 ,   47.437756 ,
#          54.240772 ,   55.218884 ,   59.507774 ,   75.54631  ,
#          57.989113 ,   57.06666  ,   80.42133  ,   52.602596 ,
#          78.33083  ,   56.843735 ,   78.52613  ,   74.86179  ,
#          53.049747 ,   52.12434  ,   74.44396  ,   76.27286  ,
#          74.124466 ,   74.63926  ,   51.81903  ,   73.77897  ,
#          57.780518 ,   72.81222  ,   55.362396 ,   75.41302  ,
#          70.82317  ,   53.569016 ,   59.795532 ,   45.605133 ,
#          58.376568 ,   55.885567 ,   44.497948 ,   57.881058 ,
#          44.121223 ,   61.502193 ,   53.76124  ,   62.97736  ,
#          55.483368 ,   62.968624 ,   53.800896 ,   51.82494  ,
#          62.288918 ,   49.603836 ,   52.04329  ,   51.369892 ,
#          63.921288 ,   53.358116 ,   50.37224  ,   39.09022  ,
#          45.537804 ,   52.552517 ,   50.435894 ,   51.536045 ,
#          54.57551  ,   37.58557  ,   46.690506 ,   51.379726 ,
#          53.502014 ,   54.234688 ,   41.0057   ,   44.222786 ,
#          52.553154 ,   50.99259  ,   39.282635 ,   45.77956  ,
#          52.59482  ,   43.405594 ,   52.187695 ,   45.77671  ,
#          43.019688 ,   43.4137   ,   48.69686  ,   52.773315 ,
#          48.21147  , -304.403    , -324.2229   , -225.24641  ,
#        -317.5484   , -273.19662  , -395.19556  , -338.20526  ,
#        -374.6563   , -337.69916  , -329.2233   , -201.78612  ,
#        -215.10739  , -328.92572  , -400.0482   , -238.56003  ,
#        -430.84113  , -398.19064  , -261.6748   , -172.61214  ,
#        -189.48268  ,   93.23827  ,  117.894936 ,  109.52539  ,
#         106.74582  ,  111.11274  ,  105.04489  ,  105.97211  ,
#         102.34111  ,  111.556786 ,  110.79985  ,  106.66265  ,
#          99.22298  ,  113.14485  ,  103.79562  ,  103.29201  ,
#         111.36714  ,   93.97627  ,  103.06533  ,   95.74018  ,
#         107.49405  ,   99.55304  ,  106.86412  ,   92.72157  ,
#         110.527664 ,  107.33977  ,   53.039864 ,   42.458588 ,
#          44.447903 ,   43.431618 ,   41.593185 ,   38.288544 ,
#          57.771652 ,   45.52471  ,   51.033966 ,   51.325615 ,
#          48.70406  ,   46.670666 ,   48.43972  ,   49.949768 ,
#          55.008343 ,   42.150867 ,   47.681347 ,   53.956806 ,
#          54.58023  ,   54.86072  ,   50.398594 ,   57.59967  ,
#          38.226124 ,   45.793736 ,   47.949825 ,   51.67613  ,
#          51.249397 , -230.60321  ,   48.371605 ,   51.036724 ,
#          51.79164  ,   47.596714 ,   47.632294 ,   50.676323 ,
#          62.259674 ,   41.44569  ,   50.22225  ,   50.5978   ,
#          44.620533 ,   55.940292 ,   45.073162 ,   50.376102 ,
#          50.661274 ,   50.246586 ,   48.537693 ,   53.28232  ,
#          44.300163 ,   46.936882 ,   71.17535  ,   59.21394  ,
#          75.4884   ,   75.33378  ,   79.02474  , -207.37363  ,
#          56.48514  ,   55.785404 ,   79.510735 ,   79.994576 ,
#          64.03221  ,   58.58761  ,   53.855083 ,   82.98839  ,
#          73.97192  ,   77.82368  ,   74.73828  ,   61.375175 ,
#          83.45426  ,   56.903236 ,   62.08256  ,   73.39772  ,
#          54.36993  ,   79.72833  ,   59.893635 ,   48.91992  ,
#          75.00289  ,   73.3724   ,   54.79738  ,   78.76072  ,
#          55.27459  ,   75.02546  ,   55.775047 ,   56.98394  ,
#          54.659973 ,   51.3499   ,   53.98661  ,   58.08141  ,
#          53.229485 ,   59.85093  , -207.17319  ,   50.431282 ,
#          58.911575 ,   62.988914 ,   58.159256 ,   77.39617  ,
#        -118.51507  ,   72.81744  ,   76.92624  ,   56.6813   ],
#       dtype=float32)

# %%
coords1[:,0]<1000
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
allsamp = samples[coords1[:,0]<1000]
arr = np.concatenate((coords1, allsamp), axis=1)

# %%
import csv         
with open('/users/mcevoysu/scratch/output/Bpendula/scikit-allel/bpendula_pca_coords.txt', 'w') as f_output:
    tsv_output = csv.writer(f_output, delimiter='\t')
    for a in arr:
        tsv_output.writerow(a)
# Out:
#   Cell In[45], line 2
#     arr = np.concatenate((coords1, samples([coords1]), axis=1)
#                                                        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
pc_het[outliers]
# Out:
# array([7.41396979, 6.98092625])

# %%
pc_missing[outliers]
# Out:
# array([0.10247595, 0.10049255])
