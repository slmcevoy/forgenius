# %%
import sys
# !{sys.executable} -m pip install --user scikit-allel

# %%
import numpy as np
import scipy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_style('ticks')
sns.set_context('notebook')
import h5py
import allel; print('scikit-allel', allel.__version__)
# Out:
# scikit-allel 1.3.8

# %% [markdown]
# ## VCF to HDF5

# %%
#allel.vcf_to_hdf5('/users/mcevoysu/scratch/output/Tbaccata/vcf_filtering/raw_SNP.vcf.gz', '/users/mcevoysu/scratch/output/Tbaccata/scikit-allel/raw_SNP.h5', fields='*')

# %% [markdown]
# ## Get data

# %%
callset_var_fn = '/users/mcevoysu/scratch/output/Tbaccata/scikit-allel/raw_SNP.h5'
callset_var = h5py.File(callset_var_fn, mode='r')

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
list(callset_var['variants'])
# Out:
# ['AC',
#  'AF',
#  'ALT',
#  'AN',
#  'BaseQRankSum',
#  'CHROM',
#  'DP',
#  'END',
#  'ExcessHet',
#  'FILTER_LowQual',
#  'FILTER_PASS',
#  'FS',
#  'ID',
#  'InbreedingCoeff',
#  'MLEAC',
#  'MLEAF',
#  'MQ',
#  'MQRankSum',
#  'POS',
#  'QD',
#  'QUAL',
#  'RAW_MQandDP',
#  'REF',
#  'ReadPosRankSum',
#  'SOR',
#  'altlen',
#  'is_snp',
#  'numalt']

# %% [markdown]
# ## Make datasets

# %%
variants = allel.VariantChunkedTable(callset_var['variants'])
variants
# Out:
# <VariantChunkedTable shape=(251638,) dtype=[('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')]
#    nbytes=43.0M cbytes=9.8M cratio=4.4
#    values=h5py._hl.group.Group>

# %%
variants_np = variants[:]
rawsnps = variants_np.query('(is_snp == True)')
rawsnps
# Out:
# <VariantTable shape=(191908,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([  1,  -1,  -1], [0.001289,      nan,      nan], [b'A', b'', b''], 774, -0.967, b'CM034146.1_1', 1862, -1, 0.    , False, False, 0., b'.', 0.2243, [  1,  -1,  -1], [0.001289,      nan,      nan], 60.  ,  0.   , 1134713, 13.53,    54.13, [-1, -1], b'C', -0.967, 0.693, [0, 0, 0],  True, 1)
#  ([ 74,  -1,  -1], [0.095   ,      nan,      nan], [b'G', b'', b''], 774,  0.   , b'CM034146.1_1', 1845, -1, 0.    , False, False, 0., b'.', 0.2962, [ 87,  -1,  -1], [0.112   ,      nan,      nan], 60.  ,  0.   , 1134715, 24.42,  7178.61, [-1, -1], b'A',  0.   , 1.594, [0, 0, 0],  True, 1)
#  ([109,  -1,  -1], [0.143   ,      nan,      nan], [b'T', b'', b''], 774,  0.   , b'CM034146.1_1', 1925, -1, 0.    , False, False, 0., b'.', 0.2397, [127,  -1,  -1], [0.164   ,      nan,      nan], 60.  ,  0.   , 1134723, 27.1 , 13846.4 , [-1, -1], b'A',  0.   , 1.642, [0, 0, 0],  True, 1)
#  ...
#  ([ 43,  11,  -1], [0.058   , 0.014   ,      nan], [b'T', b'A', b''], 774,  0.   , b'JAHRHJ020003776.1_1',  783, -1, 0.0002, False, False, 0., b'.', 0.1942, [103,  24,  -1], [0.133   , 0.031   ,      nan], 22.81, -0.431,  396514, 14.97,  2874.5 , [-1, -1], b'C',  0.   , 0.947, [0, 0, 0],  True, 2)
#  ([ 11,  -1,  -1], [0.014   ,      nan,      nan], [b'A', b'', b''], 774,  0.   , b'JAHRHJ020003776.1_1',  808, -1, 0.0002, False, False, 0., b'.', 0.2861, [ 19,  -1,  -1], [0.024   ,      nan,      nan], 22.78,  0.   ,  396516, 21.12,   760.43, [-1, -1], b'G',  0.   , 1.061, [0, 0, 0],  True, 1)
#  ([ 14,  -1,  -1], [0.018   ,      nan,      nan], [b'T', b'', b''], 774,  0.   , b'JAHRHJ020003776.1_1',  818, -1, 0.    , False, False, 0., b'.', 0.2588, [ 23,  -1,  -1], [0.03    ,      nan,      nan], 22.78,  0.253,  396523, 13.48,   552.61, [-1, -1], b'C',  0.   , 0.883, [0, 0, 0],  True, 1)]

# %%
notsnp = variants_np.query('(is_snp != True)')
notsnp
# Out:
# <VariantTable shape=(59730,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([586,  -1,  -1], [0.755,   nan,   nan], [b'*', b'', b''], 774,   nan, b'CM034146.1_1', 5543, -1, 0.    ,  True, False, 0., b'.', 0.2601, [612,  -1,  -1], [0.789,   nan,   nan], nan, nan, 1781486, 0.,  0.  , [-1, -1], b'T',    nan, 3.671, [-1,  0,  0], False, 1)
#  ([586,  -1,  -1], [0.755,   nan,   nan], [b'*', b'', b''], 774,   nan, b'CM034146.1_1', 5535, -1, 0.    ,  True, False, 0., b'.', 0.2591, [613,  -1,  -1], [0.79 ,   nan,   nan], 60.,  0., 1781487, 0.,  0.  , [-1, -1], b'A', -0.951, 3.671, [-1,  0,  0], False, 1)
#  ([586,  -1,  -1], [0.755,   nan,   nan], [b'*', b'', b''], 774, 0.789, b'CM034146.1_1', 5533, -1, 0.    ,  True, False, 0., b'.', 0.2675, [611,  -1,  -1], [0.787,   nan,   nan], 60.,  0., 1781488, 0., 13.17, [-1, -1], b'A', -1.195, 3.636, [-1,  0,  0], False, 1)
#  ...
#  ([ 26,  -1,  -1], [0.034,   nan,   nan], [b'*', b'', b''], 774,   nan, b'JAHRHJ020003660.1_1', 1623, -1, 0.0002,  True, False, 0., b'.', 0.195 , [ 34,  -1,  -1], [0.044,   nan,   nan], nan, nan,    4766, 0.,  0.  , [-1, -1], b'A',    nan, 0.498, [-1,  0,  0], False, 1)
#  ([ 20,  -1,  -1], [0.026,   nan,   nan], [b'*', b'', b''], 774,   nan, b'JAHRHJ020003660.1_1', 1338, -1, 0.0095,  True, False, 0., b'.', 0.2006, [ 28,  -1,  -1], [0.036,   nan,   nan], nan, nan,    4795, 0.,  0.  , [-1, -1], b'G',    nan, 0.272, [-1,  0,  0], False, 1)
#  ([ 20,  -1,  -1], [0.026,   nan,   nan], [b'*', b'', b''], 774,   nan, b'JAHRHJ020003660.1_1', 1344, -1, 0.0095,  True, False, 0., b'.', 0.1963, [ 28,  -1,  -1], [0.036,   nan,   nan], nan, nan,    4796, 0.,  0.  , [-1, -1], b'T',    nan, 0.272, [-1,  0,  0], False, 1)]

# %% [markdown]
# ## Plot function

# %%
def plot_hist(f, dsubset='', bins=30, ):
    if dsubset == 'var':
        x = variants[f][:]
        l = 'Variant'
    elif dsubset == 'snp':
        x = rawsnps[f][:]
        l = 'Raw SNP'
    elif dsubset == 'notsnp':
        x = notsnp[f][:]
        l = 'Raw Not SNP'
    elif dsubset == 'biallelic':
        x = biallelic_np[f][:]
        l = 'Biallelic SNP'
    elif dsubset == 'varsel':
        x = var_selection[f][:]
        l = 'Filtered Variants'
    elif dsubset == 'snpsel':
        x = snp_selection[f][:]
        l = 'Filtered SNP'
    else:
        x = bi_selection[f][:]
        l = 'Biallelic SNP'
    fig, ax = plt.subplots(figsize=(10, 5))
    sns.despine(ax=ax, offset=10)
    ax.hist(x, bins=bins)
    ax.set_xlabel(f)
    ax.set_ylabel('No. variants')
    ax.set_title('%s %s distribution' % (l, f))

# %% [markdown]
# ## Find Biallelic SNPS

# %%
numalt = rawsnps['numalt']
np.max(numalt)
# Out:
# 3

# %%
count_numalt = np.bincount(numalt)
count_numalt
# Out:
# array([     0, 187501,   4289,    118])

# %%
n_multiallelic = np.sum(count_numalt[2:])
n_multiallelic
# Out:
# 4407

# %%
filter_expression = '(numalt == 1)'
biallelic_np = rawsnps.query(filter_expression)[:]
biallelic_np
# Out:
# <VariantTable shape=(187501,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([  1,  -1,  -1], [0.001289,      nan,      nan], [b'A', b'', b''], 774, -0.967, b'CM034146.1_1', 1862, -1, 0.    , False, False, 0., b'.', 0.2243, [  1,  -1,  -1], [0.001289,      nan,      nan], 60.  , 0.   , 1134713, 13.53,    54.13, [-1, -1], b'C', -0.967, 0.693, [0, 0, 0],  True, 1)
#  ([ 74,  -1,  -1], [0.095   ,      nan,      nan], [b'G', b'', b''], 774,  0.   , b'CM034146.1_1', 1845, -1, 0.    , False, False, 0., b'.', 0.2962, [ 87,  -1,  -1], [0.112   ,      nan,      nan], 60.  , 0.   , 1134715, 24.42,  7178.61, [-1, -1], b'A',  0.   , 1.594, [0, 0, 0],  True, 1)
#  ([109,  -1,  -1], [0.143   ,      nan,      nan], [b'T', b'', b''], 774,  0.   , b'CM034146.1_1', 1925, -1, 0.    , False, False, 0., b'.', 0.2397, [127,  -1,  -1], [0.164   ,      nan,      nan], 60.  , 0.   , 1134723, 27.1 , 13846.4 , [-1, -1], b'A',  0.   , 1.642, [0, 0, 0],  True, 1)
#  ...
#  ([ 11,  -1,  -1], [0.014   ,      nan,      nan], [b'C', b'', b''], 774,  0.   , b'JAHRHJ020003776.1_1',  786, -1, 0.0002, False, False, 0., b'.', 0.2855, [ 19,  -1,  -1], [0.024   ,      nan,      nan], 22.78, 0.   ,  396512, 21.15,   761.39, [-1, -1], b'G',  0.   , 1.061, [0, 0, 0],  True, 1)
#  ([ 11,  -1,  -1], [0.014   ,      nan,      nan], [b'A', b'', b''], 774,  0.   , b'JAHRHJ020003776.1_1',  808, -1, 0.0002, False, False, 0., b'.', 0.2861, [ 19,  -1,  -1], [0.024   ,      nan,      nan], 22.78, 0.   ,  396516, 21.12,   760.43, [-1, -1], b'G',  0.   , 1.061, [0, 0, 0],  True, 1)
#  ([ 14,  -1,  -1], [0.018   ,      nan,      nan], [b'T', b'', b''], 774,  0.   , b'JAHRHJ020003776.1_1',  818, -1, 0.    , False, False, 0., b'.', 0.2588, [ 23,  -1,  -1], [0.03    ,      nan,      nan], 22.78, 0.253,  396523, 13.48,   552.61, [-1, -1], b'C',  0.   , 0.883, [0, 0, 0],  True, 1)]

# %% [markdown]
# ## MQ - RMS mapping quality

# %%
plot_hist('MQ','var') # RMS mapping quality

# %%
plot_hist('MQ','biallelic') # RMS mapping quality

# %%
filter_expression = '(MQ < 55)'
bi_selection = biallelic_np.query(filter_expression)[:]
#np.count_nonzero(var_selection)

# %%
plot_hist('MQ')

# %%
filter_expression = '(MQ < 40)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('MQ')

# %%
plot_hist('MQ','notsnp')

# %% [markdown]
# ## QD - Variant Confidence/Quality by Depth

# %%
plot_hist('QD','var') # Variant Confidence/Quality by Depth

# %%
plot_hist('QD','biallelic') # Variant Confidence/Quality by Depth

# %%
filter_expression = '(QD < 2)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('QD')

# %%
plot_hist('QD','notsnp') # Variant Confidence/Quality by Depth

# %% [markdown]
# ## SOR - Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR', 'var') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR','biallelic') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
filter_expression = '(SOR > 3)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('SOR') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR','notsnp') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %% [markdown]
# ## MQRankSum - Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','var') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','biallelic') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
filter_expression = '(MQRankSum < -12.5)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('MQRankSum') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','notsnp') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %% [markdown]
# ## ReadPosRankSum - Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','var') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','biallelic') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','notsnp') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %% [markdown]
# ## DP - Approximate read depth

# %%
plot_hist('DP','var')

# %%
plot_hist('DP','biallelic')

# %%
filter_expression = '(DP > 20000) & (DP < 40000)'
bi_selection = biallelic_np.query(filter_expression)[:]

# %%
plot_hist('DP')

# %%
plot_hist('DP','notsnp')

# %% [markdown]
# ## AN - Total number of alleles in called genotypes

# %%
plot_hist('AN','var') # Total number of alleles in called genotypes

# %%
plot_hist('AN','biallelic') # Total number of alleles in called genotypes

# %%
plot_hist('AN','notsnp') # Total number of alleles in called genotypes

# %% [markdown]
# ## Selected filter

# %%
# QD: Variant Confidence/Quality by Depth
# AN: Total number of alleles in called genotypes
filter_expression = '(QD >= 2) & (MQ >= 40) & (MQRankSum >= -12.5) & (is_snp)'
variant_selection = variants_np.eval(filter_expression)[:]
np.count_nonzero(variant_selection)
# Out:
# 160241

# %% [markdown]
# ## Genotype

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
genotypes_var = allel.GenotypeChunkedArray(calldata_var['GT'])
genotypes_var
# Out:
# <GenotypeChunkedArray shape=(251638, 387, 2) dtype=int8 chunks=(65536, 64, 2)
#    nbytes=185.7M cbytes=14.8M cratio=12.5
#    compression=gzip compression_opts=1
#    values=h5py._hl.dataset.Dataset>

# %%
# using the selected filters set above
gt_filtered_snps = genotypes_var.subset(variant_selection)
gt_filtered_snps
# Out:
# <GenotypeChunkedArray shape=(160241, 387, 2) dtype=int8 chunks=(1252, 387, 2)
#    nbytes=118.3M cbytes=19.0M cratio=6.2
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# grab the allele counts for the populations
ac = gt_filtered_snps.count_alleles()
ac
# Out:
# <AlleleCountsChunkedArray shape=(160241, 4) dtype=int32 chunks=(20031, 4)
#    nbytes=2.4M cbytes=601.1K cratio=4.2
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac[:]
# Out:
# <AlleleCountsArray shape=(160241, 4) dtype=int32>
# 773   1   0   0
# 700  74   0   0
# 665 109   0   0
# ...
# 755  19   0   0
#   8 766   0   0
# 669 105   0   0

# %%
# Which ones are biallelic?
is_biallelic_01 = ac.is_biallelic_01()[:]
ac1 = ac.compress(is_biallelic_01, axis=0)[:, :2]
ac1
##this part of the code is only for graphing the SFS, is not useful for filtering biallelic sites
# Out:
# array([[773,   1],
#        [700,  74],
#        [665, 109],
#        ...,
#        [755,  19],
#        [  8, 766],
#        [669, 105]], dtype=int32)

# %%
# plot the sfs of the derived allele
s = allel.sfs_folded(ac1)
allel.plot_sfs(s, yscale="linear", n=ac1.sum(axis=1).max())
# Out:
# <Axes: xlabel='derived allele frequency', ylabel='site frequency'>

# %%
biallelic = (ac.max_allele() == 1)
###This is the filter expression for biallelic sites
biallelic
# Out:
# <ChunkedArrayWrapper shape=(160241,) dtype=bool chunks=(160241,)
#    nbytes=156.5K cbytes=16.1K cratio=9.7
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# select only the biallelic variants
gt_biallelic = gt_filtered_snps.compress(biallelic)
gt_biallelic
# Out:
# <GenotypeChunkedArray shape=(156537, 387, 2) dtype=int8 chunks=(1223, 387, 2)
#    nbytes=115.5M cbytes=18.2M cratio=6.4
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
n_variants = len(gt_biallelic)
n_variants
# Out:
# 156537

# %%
pc_missing = gt_biallelic.count_missing(axis=0)[:] * 100 / n_variants
pc_het = gt_biallelic.count_het(axis=0)[:] * 100 / n_variants

# %% [markdown]
# ## Samples

# %%
samples_var = callset_var['samples']
samples_var = list(samples_var)
samples_var
# Out:
# [b'AUT00049-001',
#  b'AUT00049-002',
#  b'AUT00049-003',
#  b'AUT00049-005',
#  b'AUT00049-006',
#  b'AUT00049-007',
#  b'AUT00049-008',
#  b'AUT00049-009',
#  b'AUT00049-010',
#  b'AUT00049-011',
#  b'AUT00049-012',
#  b'AUT00049-013',
#  b'AUT00049-014',
#  b'AUT00049-015',
#  b'AUT00049-016',
#  b'AUT00049-017',
#  b'AUT00049-018',
#  b'AUT00049-019',
#  b'AUT00049-020',
#  b'AUT00049-021',
#  b'AUT00049-022',
#  b'AUT00049-023',
#  b'AUT00049-024',
#  b'AUT00049-025',
#  b'AUT00130-001',
#  b'AUT00130-002',
#  b'AUT00130-003',
#  b'AUT00130-004',
#  b'AUT00130-005',
#  b'AUT00130-006',
#  b'AUT00130-007',
#  b'AUT00130-008',
#  b'AUT00130-009',
#  b'AUT00130-010',
#  b'AUT00130-011',
#  b'AUT00130-012',
#  b'AUT00130-013',
#  b'AUT00130-014',
#  b'AUT00130-015',
#  b'AUT00130-016',
#  b'AUT00130-017',
#  b'AUT00130-018',
#  b'AUT00130-019',
#  b'AUT00130-020',
#  b'AUT00130-021',
#  b'AUT00130-022',
#  b'AUT00130-023',
#  b'AUT00130-024',
#  b'AUT00130-025',
#  b'AUT00185-001',
#  b'AUT00185-002',
#  b'AUT00185-003',
#  b'AUT00185-004',
#  b'AUT00185-005',
#  b'AUT00185-006',
#  b'AUT00185-007',
#  b'AUT00185-008',
#  b'AUT00185-009',
#  b'AUT00185-010',
#  b'AUT00185-011',
#  b'AUT00185-012',
#  b'AUT00185-013',
#  b'AUT00185-014',
#  b'AUT00185-015',
#  b'AUT00185-016',
#  b'AUT00185-017',
#  b'AUT00185-018',
#  b'AUT00185-019',
#  b'AUT00185-020',
#  b'AUT00185-021',
#  b'AUT00185-022',
#  b'AUT00185-023',
#  b'AUT00185-024',
#  b'AUT00185-025',
#  b'AUT00274-001',
#  b'AUT00274-002',
#  b'AUT00274-003',
#  b'AUT00274-004',
#  b'AUT00274-005',
#  b'AUT00274-006',
#  b'AUT00274-007',
#  b'AUT00274-008',
#  b'AUT00274-009',
#  b'AUT00274-010',
#  b'AUT00274-011',
#  b'AUT00274-012',
#  b'AUT00274-013',
#  b'AUT00274-014',
#  b'AUT00274-015',
#  b'AUT00274-016',
#  b'AUT00274-017',
#  b'AUT00274-018',
#  b'AUT00274-019',
#  b'AUT00274-020',
#  b'AUT00274-021',
#  b'AUT00274-022',
#  b'AUT00274-023',
#  b'AUT00274-024',
#  b'AUT00274-025',
#  b'DEU00009-001',
#  b'DEU00009-002',
#  b'DEU00009-003',
#  b'DEU00009-004',
#  b'DEU00009-005',
#  b'DEU00009-006',
#  b'DEU00009-007',
#  b'DEU00009-008',
#  b'DEU00009-009',
#  b'DEU00009-010',
#  b'DEU00009-011',
#  b'DEU00009-012',
#  b'DEU00009-013',
#  b'DEU00009-014',
#  b'DEU00009-015',
#  b'DEU00009-016',
#  b'DEU00009-017',
#  b'DEU00009-018',
#  b'DEU00009-019',
#  b'DEU00009-020',
#  b'DEU00009-021',
#  b'DEU00009-022',
#  b'DEU00009-023',
#  b'DEU00009-024',
#  b'DEU00009-025',
#  b'DEU00147-001',
#  b'DEU00147-002',
#  b'DEU00147-003',
#  b'DEU00147-004',
#  b'DEU00147-005',
#  b'DEU00147-006',
#  b'DEU00147-007',
#  b'DEU00147-008',
#  b'DEU00147-009',
#  b'DEU00147-010',
#  b'DEU00147-011',
#  b'DEU00147-012',
#  b'DEU00147-013',
#  b'DEU00147-014',
#  b'DEU00147-015',
#  b'DEU00147-016',
#  b'DEU00147-017',
#  b'DEU00147-018',
#  b'DEU00147-019',
#  b'DEU00147-020',
#  b'DEU00147-021',
#  b'DEU00147-022',
#  b'DEU00147-023',
#  b'DEU00147-024',
#  b'DEU00147-025',
#  b'ESP00078-001',
#  b'ESP00078-002',
#  b'ESP00078-003',
#  b'ESP00078-004',
#  b'ESP00078-005',
#  b'ESP00078-006',
#  b'ESP00078-007',
#  b'ESP00078-008',
#  b'ESP00078-009',
#  b'ESP00078-010',
#  b'ESP00078-011',
#  b'ESP00078-012',
#  b'ESP00078-013',
#  b'ESP00078-014',
#  b'ESP00078-015',
#  b'ESP00078-016',
#  b'ESP00078-017',
#  b'ESP00078-018',
#  b'ESP00078-019',
#  b'ESP00078-020',
#  b'ESP00078-021',
#  b'ESP00078-022',
#  b'ESP00078-023',
#  b'ESP00078-024',
#  b'ESP00078-025',
#  b'ESP00103-001',
#  b'ESP00103-002',
#  b'ESP00103-003',
#  b'ESP00103-004',
#  b'ESP00103-005',
#  b'ESP00103-006',
#  b'ESP00103-007',
#  b'ESP00103-008',
#  b'ESP00103-009',
#  b'ESP00103-010',
#  b'ESP00103-011',
#  b'ESP00103-012',
#  b'ESP00103-013',
#  b'ESP00103-014',
#  b'ESP00103-015',
#  b'ESP00103-016',
#  b'ESP00103-017',
#  b'ESP00103-018',
#  b'ESP00340-001',
#  b'ESP00340-002',
#  b'ESP00340-003',
#  b'ESP00340-004',
#  b'ESP00340-005',
#  b'ESP00340-006',
#  b'ESP00340-007',
#  b'ESP00340-008',
#  b'ESP00340-009',
#  b'ESP00340-010',
#  b'ESP00340-011',
#  b'ESP00340-012',
#  b'ESP00340-013',
#  b'ESP00340-014',
#  b'ESP00340-015',
#  b'ESP00340-016',
#  b'ESP00340-017',
#  b'ESP00340-018',
#  b'ESP00340-019',
#  b'ESP00340-020',
#  b'ESP00340-021',
#  b'ESP00340-022',
#  b'ESP00340-023',
#  b'ESP00340-024',
#  b'ESP00340-025',
#  b'GB00015-001',
#  b'GB00015-002',
#  b'GB00015-003',
#  b'GB00015-004',
#  b'GB00015-005',
#  b'GB00015-006',
#  b'GB00015-007',
#  b'GB00015-008',
#  b'GB00015-009',
#  b'GB00015-010',
#  b'GB00015-013',
#  b'GB00015-014',
#  b'GB00015-015',
#  b'GB00015-016',
#  b'GB00015-017',
#  b'GB00015-020',
#  b'GB00015-021',
#  b'GB00015-023',
#  b'GB00015-024',
#  b'GB00015-025',
#  b'GB00015-026',
#  b'GB00015-028',
#  b'GB00015-029',
#  b'GB00015-030',
#  b'GB00015-031',
#  b'ITA00023-001',
#  b'ITA00023-002',
#  b'ITA00023-003',
#  b'ITA00023-004',
#  b'ITA00023-005',
#  b'ITA00023-006',
#  b'ITA00023-007',
#  b'ITA00023-008',
#  b'ITA00023-009',
#  b'ITA00023-010',
#  b'ITA00023-011',
#  b'ITA00023-012',
#  b'ITA00023-013',
#  b'ITA00023-014',
#  b'ITA00023-015',
#  b'ITA00023-016',
#  b'ITA00023-017',
#  b'ITA00023-018',
#  b'ITA00023-019',
#  b'ITA00023-020',
#  b'ITA00023-021',
#  b'ITA00023-022',
#  b'ITA00023-023',
#  b'ITA00023-024',
#  b'ITA00023-025',
#  b'ITA00269-001',
#  b'ITA00269-002',
#  b'ITA00269-003',
#  b'ITA00269-004',
#  b'ITA00269-005',
#  b'ITA00269-006',
#  b'ITA00269-007',
#  b'ITA00269-008',
#  b'ITA00269-009',
#  b'ITA00269-010',
#  b'ITA00269-011',
#  b'ITA00269-012',
#  b'ITA00269-013',
#  b'ITA00269-014',
#  b'ITA00269-015',
#  b'ITA00269-016',
#  b'ITA00269-017',
#  b'ITA00269-018',
#  b'ITA00269-019',
#  b'ITA00269-020',
#  b'ITA00269-021',
#  b'ITA00269-022',
#  b'ITA00269-023',
#  b'ITA00269-024',
#  b'ITA00269-025',
#  b'NLD00005-001',
#  b'NLD00005-002',
#  b'NLD00005-003',
#  b'NLD00005-004',
#  b'NLD00005-005',
#  b'NLD00005-006',
#  b'NLD00005-007',
#  b'NLD00005-008',
#  b'NLD00005-009',
#  b'NLD00005-010',
#  b'NLD00005-011',
#  b'NLD00005-012',
#  b'NLD00005-013',
#  b'NLD00005-014',
#  b'NLD00005-015',
#  b'NLD00005-016',
#  b'NLD00005-017',
#  b'NLD00005-018',
#  b'NLD00005-019',
#  b'NLD00005-020',
#  b'NLD00005-021',
#  b'NLD00005-022',
#  b'NLD00005-023',
#  b'NLD00005-024',
#  b'NLD00005-025',
#  b'SVN00036-001',
#  b'SVN00036-002',
#  b'SVN00036-003',
#  b'SVN00036-004',
#  b'SVN00036-005',
#  b'SVN00036-006',
#  b'SVN00036-007',
#  b'SVN00036-008',
#  b'SVN00036-009',
#  b'SVN00036-010',
#  b'SVN00036-011',
#  b'SVN00036-012',
#  b'SVN00036-013',
#  b'SVN00036-014',
#  b'SVN00036-015',
#  b'SVN00036-016',
#  b'SVN00036-017',
#  b'SVN00036-018',
#  b'SVN00036-019',
#  b'SVN00036-020',
#  b'SVN00036-021',
#  b'SVN00036-022',
#  b'SVN00036-023',
#  b'SVN00036-024',
#  b'SVN00036-025',
#  b'TUR00224-001',
#  b'TUR00224-002',
#  b'TUR00224-003',
#  b'TUR00224-004',
#  b'TUR00224-005',
#  b'TUR00224-006',
#  b'TUR00224-007',
#  b'TUR00224-008',
#  b'TUR00224-009',
#  b'TUR00224-010',
#  b'TUR00224-011',
#  b'TUR00224-012',
#  b'TUR00224-013',
#  b'TUR00224-014',
#  b'TUR00224-015',
#  b'TUR00224-016',
#  b'TUR00224-017',
#  b'TUR00224-018',
#  b'TUR00224-019',
#  b'TUR00224-020',
#  b'TUR00224-021',
#  b'TUR00224-022',
#  b'TUR00224-023',
#  b'TUR00224-024',
#  b'TUR00224-025',
#  b'TUR00283-001',
#  b'TUR00283-002',
#  b'TUR00283-003',
#  b'TUR00283-004',
#  b'TUR00283-005',
#  b'TUR00283-006',
#  b'TUR00283-007',
#  b'TUR00283-008',
#  b'TUR00283-009',
#  b'TUR00283-010',
#  b'TUR00283-011',
#  b'TUR00283-012',
#  b'TUR00283-013',
#  b'TUR00283-014',
#  b'TUR00283-015',
#  b'TUR00283-016',
#  b'TUR00283-017',
#  b'TUR00283-018',
#  b'TUR00283-019',
#  b'TUR00283-020']

# %%
samples_fn = '~/scratch/data/Tbaccata/Tbaccata_sample_list_scikit-allel.txt'
samples = pandas.read_csv(samples_fn, sep='\t')
samples
# Out:
#                ID Population
# 0    AUT00049-001   AUT00049
# 1    AUT00049-002   AUT00049
# 2    AUT00049-003   AUT00049
# 3    AUT00049-005   AUT00049
# 4    AUT00049-006   AUT00049
# ..            ...        ...
# 382  TUR00283-016   TUR00283
# 383  TUR00283-017   TUR00283
# 384  TUR00283-018   TUR00283
# 385  TUR00283-019   TUR00283
# 386  TUR00283-020   TUR00283
#
# [387 rows x 2 columns]

# %%
samples.Population.value_counts()
# Out:
# Population
# AUT00130    25
# AUT00185    25
# AUT00274    25
# DEU00009    25
# ESP00078    25
# DEU00147    25
# GB00015     25
# ESP00340    25
# NLD00005    25
# SVN00036    25
# ITA00023    25
# ITA00269    25
# TUR00224    25
# AUT00049    24
# TUR00283    20
# ESP00103    18
# Name: count, dtype: int64

# %%
populations = samples.Population.unique()
populations
###This identifiers come from the metadata file
# Out:
# array(['AUT00049', 'AUT00130', 'AUT00185', 'AUT00274', 'DEU00009',
#        'DEU00147', 'ESP00078', 'ESP00103', 'ESP00340', 'GB00015',
#        'ITA00023', 'ITA00269', 'NLD00005', 'SVN00036', 'TUR00224',
#        'TUR00283'], dtype=object)

# %% [markdown]
# ## Gt frequency function

# %%
def plot_genotype_frequency(pc, title):
    fig, ax = plt.subplots(figsize=(24, 5))
    sns.despine(ax=ax, offset=24)
    left = np.arange(len(pc))
    palette = sns.color_palette("hls", 16)
    pop2color = {'AUT00049': palette[0],
                 'AUT00130': palette[8],
                 'AUT00185': palette[1],
                 'AUT00274': palette[9],
                 'DEU00009': palette[2],
                 'DEU00147': palette[10],
                 'ESP00078': palette[3],
                 'ESP00103': palette[11],
                 'ESP00340': palette[4],
                 'GB00015': palette[12],
                 'ITA00023': palette[5],
                 'ITA00269': palette[13],
                 'NLD00005': palette[6],
                 'SVN00036': palette[14],
                 'TUR00224': palette[7],
                 'TUR00283': palette[15]                 
                 }
    colors = [pop2color[p] for p in samples.Population]
    ax.bar(left, pc, color=colors)
    ax.set_xlim(0, len(pc))
    ax.set_xlabel('Sample index')
    ax.set_ylabel('Percent calls')
    ax.set_title(title)
    handles = [mpl.patches.Patch(color=palette[0]),
               mpl.patches.Patch(color=palette[8]),
               mpl.patches.Patch(color=palette[1]),
               mpl.patches.Patch(color=palette[9]),
               mpl.patches.Patch(color=palette[2]),
               mpl.patches.Patch(color=palette[10]),
               mpl.patches.Patch(color=palette[3]),
               mpl.patches.Patch(color=palette[11]),
               mpl.patches.Patch(color=palette[4]),
               mpl.patches.Patch(color=palette[12]),
               mpl.patches.Patch(color=palette[5]),
               mpl.patches.Patch(color=palette[13]),
               mpl.patches.Patch(color=palette[6]),
               mpl.patches.Patch(color=palette[14]),
               mpl.patches.Patch(color=palette[7]),
               mpl.patches.Patch(color=palette[15])]
    ax.legend(handles=handles, labels=['AUT00049', 'AUT00130', 'AUT00185', 'AUT00274', 'DEU00009',
       'DEU00147', 'ESP00078', 'ESP00103', 'ESP00340', 'GB00015',
       'ITA00023', 'ITA00269', 'NLD00005', 'SVN00036', 'TUR00224',
       'TUR00283'], title='Population',
              bbox_to_anchor=(1, 1), loc='upper left')

# %% [markdown]
# ## Plot missing

# %%
plot_genotype_frequency(pc_missing, 'Missing')

# %% [markdown]
# ## Plot heterozygosity

# %%
plot_genotype_frequency(pc_het, 'Heterozygosity')

# %% [markdown]
# ## PCA

# %%
palette = sns.color_palette("hls",16)
pop_colours = {    
                 'AUT00049': palette[0],
                 'AUT00130': palette[8],
                 'AUT00185': palette[1],
                 'AUT00274': palette[9],
                 'DEU00009': palette[2],
                 'DEU00147': palette[10],
                 'ESP00078': palette[3],
                 'ESP00103': palette[11],
                 'ESP00340': palette[4],
                 'GB00015': palette[12],
                 'ITA00023': palette[5],
                 'ITA00269': palette[13],
                 'NLD00005': palette[6],
                 'SVN00036': palette[14],
                 'TUR00224': palette[7],
                 'TUR00283': palette[15]
}

# %%
def plot_pca_coords(coords, model, pc1, pc2, ax, sample_population):
    sns.despine(ax=ax, offset=5)
    x = coords[:, pc1]
    y = coords[:, pc2]
    for pop in populations:
        flt = (sample_population == pop)
        ax.plot(x[flt], y[flt], marker='o', linestyle=' ', color=pop_colours[pop], 
                label=pop, markersize=6, mec='k', mew=.5)
    ax.set_xlabel('PC%s (%.1f%%)' % (pc1+1, model.explained_variance_ratio_[pc1]*100))
    ax.set_ylabel('PC%s (%.1f%%)' % (pc2+1, model.explained_variance_ratio_[pc2]*100))
    

def fig_pca(coords, model, title, sample_population=None):
    if sample_population is None:
        sample_population = samples.Population
    # plot coords for PCs 1 vs 2, 3 vs 4
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 2, 1)
    plot_pca_coords(coords, model, 0, 1, ax, sample_population)
    ax = fig.add_subplot(1, 2, 2)
    plot_pca_coords(coords, model, 2, 3, ax, sample_population)
    ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
    fig.suptitle(title, y=1.02)
    fig.tight_layout()

# %%
ac2 = gt_biallelic.count_alleles()
ac2
# Out:
# <AlleleCountsChunkedArray shape=(156537, 2) dtype=int32 chunks=(39135, 2)
#    nbytes=1.2M cbytes=430.2K cratio=2.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
flt = (ac2[:, :2].min(axis=1) > 1)
gf = gt_biallelic.compress(flt, axis=0)
gn = gf.to_n_alt()
gn
# Out:
# <ChunkedArrayWrapper shape=(129396, 387) dtype=int8 chunks=(2022, 387)
#    nbytes=47.8M cbytes=11.6M cratio=4.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
coords1, model1 = allel.pca(gn, n_components=10, scaler='patterson')

# %%
fig_pca(coords1, model1, 'Figure 1. Conventional PCA.')

# %%
outliers = coords1[:,0]>600
samples[outliers]
# Out:
#                ID Population
# 160  ESP00078-012   ESP00078
# 260  ITA00023=019   ITA00023
# 311  NLD00005-020   NLD00005
# 330  SVN00036-014   SVN00036
# 341  SVN00036-025   SVN00036
# 367  TUR00283-001   TUR00283
# 368  TUR00283-002   TUR00283

# %%
pc_het[outliers]
# Out:
# array([0.02108128, 0.01980362, 1.19396692, 0.58388752, 0.05238378,
#        0.03769077, 0.01022123])

# %%
pc_missing[outliers]
# Out:
# array([0.00447179, 0.00063883, 0.04599552, 0.00574944, 0.00319413,
#        0.00255531, 0.        ])
