# %%
import sys
# !{sys.executable} -m pip install --user scikit-allel

# %%
import numpy as np
import scipy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_style('ticks')
sns.set_context('notebook')
import h5py
import allel; print('scikit-allel', allel.__version__)
# Out:
# scikit-allel 1.3.8

# %% [markdown]
# ## VCF to HDF5

# %%
#allel.vcf_to_hdf5('/users/mcevoysu/scratch/output/Bpendula/vcf_filtering/Bpendula_SNP_sampleFilt_random_locimissingness_V1.vcf.gz', '/users/mcevoysu/scratch/output/Bpendula/scikit-allel/Bpendula_SNP_sampleFilt_random_locimissingness_V1.h5', fields='*')

# %% [markdown]
# ## Get data

# %%
callset_var_fn = '/users/mcevoysu/scratch/output/Bpendula/scikit-allel/Bpendula_SNP_sampleFilt_random_locimissingness_V1.h5'
callset_var = h5py.File(callset_var_fn, mode='r')

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
list(callset_var['variants'])
# Out:
# ['AC',
#  'AF',
#  'ALT',
#  'AN',
#  'BaseQRankSum',
#  'CHROM',
#  'DP',
#  'END',
#  'ExcessHet',
#  'FILTER_FILT',
#  'FILTER_LowQual',
#  'FILTER_PASS',
#  'FS',
#  'ID',
#  'InbreedingCoeff',
#  'MLEAC',
#  'MLEAF',
#  'MQ',
#  'MQRankSum',
#  'POS',
#  'QD',
#  'QUAL',
#  'RAW_MQandDP',
#  'REF',
#  'ReadPosRankSum',
#  'SOR',
#  'altlen',
#  'is_snp',
#  'numalt']

# %% [markdown]
# ## Make datasets

# %%
variants = allel.VariantChunkedTable(callset_var['variants'])
variants
# Out:
# <VariantChunkedTable shape=(66494,) dtype=[('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_FILT', '?'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')]
#    nbytes=11.4M cbytes=2.8M cratio=4.1
#    values=h5py._hl.group.Group>

# %%
variants_np = variants[:]
variants_np
# Out:
# <VariantTable shape=(66494,) dtype=(numpy.record, [('AC', '<i4', (3,)), ('AF', '<f4', (3,)), ('ALT', 'O', (3,)), ('AN', '<i4'), ('BaseQRankSum', '<f4'), ('CHROM', 'O'), ('DP', '<i4'), ('END', '<i4'), ('ExcessHet', '<f4'), ('FILTER_FILT', '?'), ('FILTER_LowQual', '?'), ('FILTER_PASS', '?'), ('FS', '<f4'), ('ID', 'O'), ('InbreedingCoeff', '<f4'), ('MLEAC', '<i4', (3,)), ('MLEAF', '<f4', (3,)), ('MQ', '<f4'), ('MQRankSum', '<f4'), ('POS', '<i4'), ('QD', '<f4'), ('QUAL', '<f4'), ('RAW_MQandDP', '<i4', (2,)), ('REF', 'O'), ('ReadPosRankSum', '<f4'), ('SOR', '<f4'), ('altlen', '<i4', (3,)), ('is_snp', '?'), ('numalt', '<i4')])>
# [([  1,  -1,  -1], [0.001351,      nan,      nan], [b'C', b'', b''], 666,  0.962, b'Contig0', 16693, -1, 0.    , False, False,  True,  0.   , b'.', 0.3746, [  1,  -1,  -1], [0.001351,      nan,      nan], 60., 0.,  36198, 15.16, 3.33470e+02, [-1, -1], b'T',  1.52 , 0.649, [0, 0, 0],  True, 1)
#  ([436,  -1,  -1], [0.654   ,      nan,      nan], [b'G', b'', b''], 636, -0.043, b'Contig0', 17345, -1, 1.5801, False, False,  True,  0.   , b'.', 0.0167, [492,  -1,  -1], [0.665   ,      nan,      nan], 60., 0.,  36209, 23.87, 3.72008e+05, [-1, -1], b'A', -0.128, 0.644, [0, 0, 0],  True, 1)
#  ([ 12,  -1,  -1], [0.031   ,      nan,      nan], [b'T', b'', b''], 648,  0.66 , b'Contig0', 17175, -1, 1.5489, False, False,  True,  1.013, b'.', 0.0582, [ 21,  -1,  -1], [0.028   ,      nan,      nan], 60., 0.,  36221,  3.82, 2.40602e+03, [-1, -1], b'A',  0.353, 0.871, [0, 0, 0],  True, 1)
#  ...
#  ([  4,  -1,  -1], [0.012   ,      nan,      nan], [b'C', b'', b''], 360,  0.   , b'Contig996',  4133, -1, 0.2235, False, False,  True,  0.   , b'.', 0.1643, [ 10,  -1,  -1], [0.014   ,      nan,      nan], 60., 0., 209575, 18.69, 1.43924e+03, [-1, -1], b'G',  1.07 , 0.305, [0, 0, 0],  True, 1)
#  ([ 16,  -1,  -1], [0.036   ,      nan,      nan], [b'G', b'', b''], 522,  0.   , b'Contig999',  5320, -1, 0.    , False, False,  True, 12.35 , b'.', 0.3316, [ 26,  -1,  -1], [0.035   ,      nan,      nan], 60., 0.,   3184, 21.25, 6.75756e+03, [-1, -1], b'A', -1.645, 1.313, [0, 0, 0],  True, 1)
#  ([  2,  -1,  -1], [0.004054,      nan,      nan], [b'A', b'', b''], 512, -0.977, b'Contig999',  5342, -1, 0.019 , False, False,  True,  2.477, b'.', 0.3955, [  3,  -1,  -1], [0.004054,      nan,      nan], 60., 0.,   3195,  9.69, 4.94100e+02, [-1, -1], b'G', -0.674, 0.388, [0, 0, 0],  True, 1)]

# %% [markdown]
# ## Plot function

# %%
def plot_hist(f, dsubset='', bins=30, ):
    if dsubset == 'var':
        x = variants[f][:]
        l = 'Variant'
    elif dsubset == 'snp':
        x = rawsnps[f][:]
        l = 'Raw SNP'
    elif dsubset == 'notsnp':
        x = notsnp[f][:]
        l = 'Raw Not SNP'
    elif dsubset == 'biallelic':
        x = biallelic_np[f][:]
        l = 'Biallelic SNP'
    elif dsubset == 'varsel':
        x = var_selection[f][:]
        l = 'Filtered Variants'
    elif dsubset == 'snpsel':
        x = snp_selection[f][:]
        l = 'Filtered SNP'
    else:
        x = bi_selection[f][:]
        l = 'Biallelic SNP'
    fig, ax = plt.subplots(figsize=(10, 5))
    sns.despine(ax=ax, offset=10)
    ax.hist(x, bins=bins)
    ax.set_xlabel(f)
    ax.set_ylabel('No. variants')
    ax.set_title('%s %s distribution' % (l, f))

# %% [markdown]
# ## MQ - RMS mapping quality

# %%
plot_hist('MQ','var') # RMS mapping quality

# %%
filter_expression = '(MQ < 55)'

# %%
plot_hist('MQ')

# %%
filter_expression = '(MQ < 40)'

# %%
plot_hist('MQ')

# %% [markdown]
# ## QD - Variant Confidence/Quality by Depth

# %%
plot_hist('QD','var') # Variant Confidence/Quality by Depth

# %%
filter_expression = '(QD < 2)'

# %%
plot_hist('QD')

# %% [markdown]
# ## SOR - Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
plot_hist('SOR', 'var') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %%
filter_expression = '(SOR > 3)'

# %%
plot_hist('SOR') # Symmetric Odds Ratio of 2x2 contingency table to detect strand bias

# %% [markdown]
# ## MQRankSum - Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
plot_hist('MQRankSum','var') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %%
filter_expression = '(MQRankSum < -12.5)'

# %%
plot_hist('MQRankSum') # Z-score From Wilcoxon rank sum test of Alt vs. Ref read mapping qualities

# %% [markdown]
# ## ReadPosRankSum - Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %%
plot_hist('ReadPosRankSum','var') # Z-score from Wilcoxon rank sum test of Alt vs. Ref read position bias

# %% [markdown]
# ## DP - Approximate read depth

# %%
plot_hist('DP','var')

# %%
filter_expression = '(DP > 20000) & (DP < 40000)'

# %%
plot_hist('DP')

# %% [markdown]
# ## AN - Total number of alleles in called genotypes

# %%
plot_hist('AN','var') # Total number of alleles in called genotypes

# %%
# QD: Variant Confidence/Quality by Depth
# AN: Total number of alleles in called genotypes
filter_expression = '(QD >= 2) & (MQ >= 40) & (MQRankSum >= -12.5) & (is_snp)'
variant_selection = variants_np.eval(filter_expression)[:]
np.count_nonzero(variant_selection)
# Out:
# 66254

# %% [markdown]
# ## Genotype

# %%
calldata_var = callset_var['calldata']
list(calldata_var)
# Out:
# ['AD', 'DP', 'GQ', 'GT', 'MIN_DP', 'PGT', 'PID', 'PL', 'PS', 'RGQ', 'SB']

# %%
genotypes_var = allel.GenotypeChunkedArray(calldata_var['GT'])
genotypes_var
# Out:
# <GenotypeChunkedArray shape=(66494, 351, 2) dtype=int8 chunks=(65536, 64, 2)
#    nbytes=44.5M cbytes=5.8M cratio=7.7
#    compression=gzip compression_opts=1
#    values=h5py._hl.dataset.Dataset>

# %%
# using the selected filters set above
gt_filtered_snps = genotypes_var.subset(variant_selection)
gt_filtered_snps
# Out:
# <GenotypeChunkedArray shape=(66254, 351, 2) dtype=int8 chunks=(1036, 351, 2)
#    nbytes=44.4M cbytes=10.7M cratio=4.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# grab the allele counts for the populations
ac = genotypes_var.count_alleles()
ac
# Out:
# <AlleleCountsChunkedArray shape=(66494, 2) dtype=int32 chunks=(33247, 2)
#    nbytes=519.5K cbytes=165.6K cratio=3.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac[:]
# Out:
# <AlleleCountsArray shape=(66494, 2) dtype=int32>
# 665   1
# 200 436
# 636  12
# ...
# 356   4
# 506  16
# 510   2

# %%
# Which ones are biallelic?
is_biallelic_01 = ac.is_biallelic_01()[:]
ac1 = ac.compress(is_biallelic_01, axis=0)[:, :2]
ac1
##this part of the code is only for graphing the SFS, is not useful for filtering biallelic sites
# Out:
# <AlleleCountsArray shape=(66279, 2) dtype=int32>
# 665   1
# 200 436
# 636  12
# ...
# 356   4
# 506  16
# 510   2

# %%
# plot the sfs of the derived allele
s = allel.sfs_folded(ac1)
allel.plot_sfs(s, yscale="linear", n=ac1.sum(axis=1).max())
# Out:
# <Axes: xlabel='derived allele frequency', ylabel='site frequency'>

# %%
biallelic = (ac.max_allele() == 1)
###This is the filter expression for biallelic sites
biallelic
# Out:
# <ChunkedArrayWrapper shape=(66494,) dtype=bool chunks=(66494,)
#    nbytes=64.9K cbytes=1.6K cratio=40.2
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
# select only the biallelic variants
gt_biallelic = genotypes_var.compress(biallelic)
gt_biallelic
# Out:
# <GenotypeChunkedArray shape=(66279, 351, 2) dtype=int8 chunks=(1036, 351, 2)
#    nbytes=44.4M cbytes=10.7M cratio=4.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
n_variants = len(gt_biallelic)
n_variants
# Out:
# 66279

# %%
pc_missing = gt_biallelic.count_missing(axis=0)[:] * 100 / n_variants
pc_het = gt_biallelic.count_het(axis=0)[:] * 100 / n_variants

# %%
list(pc_het)
# Out:
# [7.276814677348783,
#  8.364640383831983,
#  8.654324899289367,
#  8.797658383500053,
#  6.706498287542057,
#  6.99165648244542,
#  7.68418352721073,
#  8.367657930867997,
#  7.976885589704129,
#  9.549027595467644,
#  8.968149791034868,
#  4.752636581722718,
#  8.504956321006654,
#  6.673305270145899,
#  7.789797673471235,
#  8.136815582612893,
#  7.503130705049865,
#  3.305722777953801,
#  6.551094615187314,
#  8.693553010757554,
#  9.1839044041099,
#  9.665203156354199,
#  4.2109868887581285,
#  6.37456811358047,
#  3.8820742618325563,
#  5.274672218953213,
#  5.781620121003636,
#  9.704431267822388,
#  10.911450082228157,
#  7.9286048371278985,
#  9.100921860619502,
#  8.790114515910016,
#  10.380361803889619,
#  9.17334298948385,
#  9.601834668597897,
#  8.815763665716139,
#  10.17365983192263,
#  7.5649904192881605,
#  10.107273797130313,
#  8.903272529760558,
#  10.187238793584696,
#  7.915025875465834,
#  11.55871392145325,
#  8.746360083887808,
#  10.578011134748563,
#  4.4252327283151525,
#  9.143167519123704,
#  4.444846784049246,
#  4.553478477345766,
#  4.690776867484422,
#  4.831092804659092,
#  4.719443564326559,
#  4.873338463163295,
#  5.390847779839768,
#  4.545934609755729,
#  5.166040525656694,
#  5.6428129573469725,
#  4.429759048869174,
#  5.375760044659696,
#  4.656075076570256,
#  4.278881697068453,
#  5.286742407097271,
#  5.823865779507838,
#  4.776776958010833,
#  5.583970790144692,
#  4.384495843328958,
#  5.526637396460417,
#  4.631934700282141,
#  4.665127717678299,
#  4.586671494741925,
#  4.6455136619442055,
#  5.327479292083465,
#  4.98951402404985,
#  3.7930566242701307,
#  4.8386366722491285,
#  7.112358363885997,
#  3.8051268124141884,
#  5.019689494409994,
#  4.819022616515035,
#  4.8823911042713375,
#  5.419514476681905,
#  7.655516830368593,
#  5.261093257291148,
#  5.482882964438208,
#  4.90804025407746]

# %%
gt_biallelic
# Out:
# <GenotypeChunkedArray shape=(66279, 351, 2) dtype=int8 chunks=(1036, 351, 2)
#    nbytes=44.4M cbytes=10.7M cratio=4.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %% [markdown]
# ## Samples

# %%
callset_var['samples']
# Out:
# <HDF5 dataset "samples": shape (351,), type "|O">

# %%
#samples_var = callset_var['samples']
#samples_var = list(samples_var)
samples_var = [x.decode() for x in callset_var['samples']]
samples_var
# Out:
# ['ESP00102-001',
#  'ESP00102-002',
#  'ESP00102-003',
#  'ESP00102-004',
#  'ESP00102-005',
#  'ESP00102-006',
#  'ESP00102-007',
#  'ESP00102-008',
#  'ESP00102-009',
#  'ESP00102-010',
#  'ESP00102-011',
#  'ESP00102-012',
#  'ESP00102-014',
#  'ESP00102-017',
#  'ESP00102-018',
#  'ESP00102-019',
#  'ESP00102-020',
#  'ESP00102-021',
#  'ESP00102-022',
#  'ESP00102-023',
#  'ESP00102-024',
#  'ESP00102-025',
#  'ESP00199-001',
#  'ESP00199-002',
#  'ESP00199-003',
#  'ESP00199-004',
#  'ESP00199-005',
#  'ESP00199-006',
#  'ESP00199-007',
#  'ESP00199-008',
#  'ESP00199-009',
#  'ESP00199-010',
#  'ESP00199-011',
#  'ESP00199-012',
#  'ESP00199-013',
#  'ESP00199-014',
#  'ESP00199-015',
#  'ESP00199-016',
#  'ESP00199-017',
#  'ESP00199-018',
#  'ESP00199-019',
#  'ESP00199-020',
#  'ESP00199-021',
#  'ESP00199-022',
#  'ESP00199-023',
#  'ESP00199-024',
#  'ESP00199-025',
#  'ESP00337-001',
#  'ESP00337-002',
#  'ESP00337-003',
#  'ESP00337-004',
#  'ESP00337-005',
#  'ESP00337-006',
#  'ESP00337-007',
#  'ESP00337-008',
#  'ESP00337-009',
#  'ESP00337-010',
#  'ESP00337-011',
#  'ESP00337-012',
#  'ESP00337-013',
#  'ESP00337-014',
#  'ESP00337-015',
#  'ESP00337-016',
#  'ESP00337-017',
#  'ESP00337-018',
#  'ESP00337-019',
#  'ESP00337-020',
#  'ESP00337-021',
#  'ESP00337-022',
#  'ESP00337-023',
#  'ESP00337-024',
#  'ESP00337-025',
#  'FIN00015-001',
#  'FIN00015-002',
#  'FIN00015-003',
#  'FIN00015-004',
#  'FIN00015-005',
#  'FIN00015-006',
#  'FIN00015-007',
#  'FIN00015-008',
#  'FIN00015-009',
#  'FIN00015-010',
#  'FIN00015-011',
#  'FIN00015-012',
#  'FIN00015-013',
#  'FIN00015-015',
#  'FIN00015-016',
#  'FIN00015-017',
#  'FIN00015-018',
#  'FIN00015-019',
#  'FIN00015-021',
#  'FIN00015-022',
#  'FIN00015-023',
#  'FIN00015-024',
#  'FIN00020-001',
#  'FIN00020-002',
#  'FIN00020-003',
#  'FIN00020-004',
#  'FIN00020-005',
#  'FIN00020-006',
#  'FIN00020-007',
#  'FIN00020-008',
#  'FIN00020-009',
#  'FIN00020-010',
#  'FIN00020-011',
#  'FIN00020-012',
#  'FIN00020-014',
#  'FIN00020-015',
#  'FIN00020-016',
#  'FIN00020-017',
#  'FIN00020-018',
#  'FIN00020-020',
#  'FIN00020-021',
#  'FIN00020-022',
#  'FIN00020-023',
#  'FIN00020-024',
#  'FIN00044-001',
#  'FIN00044-002',
#  'FIN00044-004',
#  'FIN00044-005',
#  'FIN00044-006',
#  'FIN00044-007',
#  'FIN00044-009',
#  'FIN00044-010',
#  'FIN00044-012',
#  'FIN00044-013',
#  'FIN00044-014',
#  'FIN00044-015',
#  'FIN00044-016',
#  'FIN00044-017',
#  'FIN00044-018',
#  'FIN00044-019',
#  'FIN00044-020',
#  'FIN00044-021',
#  'FIN00044-022',
#  'FIN00044-023',
#  'FIN00044-024',
#  'FIN00044-025',
#  'FIN00046-001',
#  'FIN00046-002',
#  'FIN00046-003',
#  'FIN00046-004',
#  'FIN00046-006',
#  'FIN00046-007',
#  'FIN00046-008',
#  'FIN00046-009',
#  'FIN00046-010',
#  'FIN00046-011',
#  'FIN00046-012',
#  'FIN00046-013',
#  'FIN00046-014',
#  'FIN00046-015',
#  'FIN00046-016',
#  'FIN00046-017',
#  'FIN00046-018',
#  'FIN00046-019',
#  'FIN00046-020',
#  'FIN00046-021',
#  'FIN00046-022',
#  'FIN00046-023',
#  'FIN00046-024',
#  'FIN00046-025',
#  'GBR00013-001',
#  'GBR00013-002',
#  'GBR00013-003',
#  'GBR00013-004',
#  'GBR00013-005',
#  'GBR00013-006',
#  'GBR00013-007',
#  'GBR00013-008',
#  'GBR00013-009',
#  'GBR00013-010',
#  'GBR00013-013',
#  'GBR00013-014',
#  'GBR00013-015',
#  'GBR00013-016',
#  'GBR00013-017',
#  'GBR00013-018',
#  'GBR00013-019',
#  'GBR00013-020',
#  'GBR00013-021',
#  'GBR00013-022',
#  'GBR00013-023',
#  'GBR00013-024',
#  'GBR00013-025',
#  'GBR00015-101',
#  'GBR00015-102',
#  'GBR00015-103',
#  'GBR00015-104',
#  'GBR00015-105',
#  'GBR00015-106',
#  'GBR00015-107',
#  'GBR00015-108',
#  'GBR00015-109',
#  'GBR00015-110',
#  'GBR00015-111',
#  'GBR00015-112',
#  'GBR00015-113',
#  'GBR00015-114',
#  'GBR00015-115',
#  'GBR00015-116',
#  'GBR00015-117',
#  'GBR00015-118',
#  'GBR00015-119',
#  'GBR00015-120',
#  'GBR00015-121',
#  'GBR00015-122',
#  'GBR00015-123',
#  'GBR00015-124',
#  'IRL00017-001',
#  'IRL00017-002',
#  'IRL00017-003',
#  'IRL00017-004',
#  'IRL00017-005',
#  'IRL00017-006',
#  'IRL00017-007',
#  'IRL00017-008',
#  'IRL00017-009',
#  'IRL00017-010',
#  'IRL00017-011',
#  'IRL00017-012',
#  'IRL00017-013',
#  'IRL00017-014',
#  'IRL00017-015',
#  'IRL00017-016',
#  'IRL00017-017',
#  'IRL00017-018',
#  'IRL00017-019',
#  'IRL00017-020',
#  'ITA00243-001',
#  'ITA00243-002',
#  'ITA00243-003',
#  'ITA00243-004',
#  'ITA00243-005',
#  'ITA00243-006',
#  'ITA00243-008',
#  'ITA00243-009',
#  'ITA00243-010',
#  'ITA00243-011',
#  'ITA00243-012',
#  'ITA00243-013',
#  'ITA00243-014',
#  'ITA00243-015',
#  'ITA00243-016',
#  'ITA00243-017',
#  'ITA00243-018',
#  'ITA00243-019',
#  'ITA00243-020',
#  'ITA00243-021',
#  'ITA00243-022',
#  'ITA00243-023',
#  'ITA00243-024',
#  'ITA00243-025',
#  'ITA00248-001',
#  'ITA00248-002',
#  'ITA00248-003',
#  'ITA00248-004',
#  'ITA00248-005',
#  'ITA00248-006',
#  'ITA00248-007',
#  'ITA00248-009',
#  'ITA00248-010',
#  'ITA00248-011',
#  'ITA00248-012',
#  'ITA00248-013',
#  'ITA00248-014',
#  'ITA00248-015',
#  'ITA00248-017',
#  'ITA00248-018',
#  'ITA00248-019',
#  'ITA00248-020',
#  'ITA00248-021',
#  'ITA00248-022',
#  'ITA00248-023',
#  'ITA00248-024',
#  'ITA00248-025',
#  'LUX00021-001',
#  'LUX00021-002',
#  'LUX00021-003',
#  'LUX00021-004',
#  'LUX00021-005',
#  'LUX00021-006',
#  'LUX00021-007',
#  'LUX00021-008',
#  'LUX00021-009',
#  'LUX00021-010',
#  'LUX00021-011',
#  'LUX00021-012',
#  'LUX00021-013',
#  'LUX00021-014',
#  'LUX00021-015',
#  'LUX00021-016',
#  'LUX00021-017',
#  'LUX00021-018',
#  'LUX00021-019',
#  'LUX00021-020',
#  'LUX00021-021',
#  'LUX00021-022',
#  'LUX00021-023',
#  'LUX00021-024',
#  'LUX00021-025',
#  'NLD00013-001',
#  'NLD00013-002',
#  'NLD00013-003',
#  'NLD00013-004',
#  'NLD00013-005',
#  'NLD00013-006',
#  'NLD00013-007',
#  'NLD00013-008',
#  'NLD00013-009',
#  'NLD00013-010',
#  'NLD00013-011',
#  'NLD00013-012',
#  'NLD00013-013',
#  'NLD00013-014',
#  'NLD00013-015',
#  'NLD00013-016',
#  'NLD00013-017',
#  'NLD00013-018',
#  'NLD00013-019',
#  'NLD00013-020',
#  'NLD00013-021',
#  'NLD00013-022',
#  'NLD00013-023',
#  'NLD00013-024',
#  'NLD00013-025',
#  'SWE00093-001',
#  'SWE00093-002',
#  'SWE00093-003',
#  'SWE00093-004',
#  'SWE00093-005',
#  'SWE00093-006',
#  'SWE00093-007',
#  'SWE00093-008',
#  'SWE00093-009',
#  'SWE00093-010',
#  'SWE00093-011',
#  'SWE00093-012',
#  'SWE00093-013',
#  'SWE00093-014',
#  'SWE00093-015',
#  'SWE00093-016',
#  'SWE00093-017',
#  'SWE00093-018',
#  'SWE00093-019',
#  'SWE00093-020',
#  'SWE00093-021',
#  'SWE00093-022',
#  'SWE00093-023',
#  'SWE00093-024',
#  'SWE00093-025']

# %%
samples_fn = '~/scratch/data/Bpendula/Betula_pendula_sample_list_scikit-allel_V1.txt'
samples = pandas.read_csv(samples_fn, sep='\t')
samples
# Out:
#                ID Population
# 0    ESP00102-001   ESP00102
# 1    ESP00102-002   ESP00102
# 2    ESP00102-003   ESP00102
# 3    ESP00102-004   ESP00102
# 4    ESP00102-005   ESP00102
# ..            ...        ...
# 346  SWE00093-021   SWE00093
# 347  SWE00093-022   SWE00093
# 348  SWE00093-023   SWE00093
# 349  SWE00093-024   SWE00093
# 350  SWE00093-025   SWE00093
#
# [351 rows x 2 columns]

# %%
samples.Population.value_counts()
# Out:
# Population
# ESP00199    25
# ESP00337    25
# NLD00013    25
# SWE00093    25
# LUX00021    25
# GBR00015    24
# FIN00046    24
# ITA00243    24
# GBR00013    23
# ITA00248    23
# ESP00102    22
# FIN00044    22
# FIN00020    22
# FIN00015    22
# IRL00017    20
# Name: count, dtype: int64

# %%
populations = samples.Population.unique()
populations
###This identifiers come from the metadata file
# Out:
# array(['ESP00102', 'ESP00199', 'ESP00337', 'FIN00015', 'FIN00020',
#        'FIN00044', 'FIN00046', 'GBR00013', 'GBR00015', 'IRL00017',
#        'ITA00243', 'ITA00248', 'LUX00021', 'NLD00013', 'SWE00093'],
#       dtype=object)

# %% [markdown]
# ## Gt frequency function

# %%
def plot_genotype_frequency(pc, title):
    fig, ax = plt.subplots(figsize=(24, 5))
    sns.despine(ax=ax, offset=24)
    left = np.arange(len(pc))
    palette = sns.color_palette("hls", 15)
    pop2color = {'ESP00102': palette[0],
                 'ESP00199': palette[8],
                 'ESP00337': palette[1],
                 'FIN00015': palette[9],
                 'FIN00020': palette[2],
                 'FIN00044': palette[10],
                 'FIN00046': palette[3],
                 'GBR00013': palette[11],
                 'GBR00015': palette[4],
                 'IRL00017': palette[12],
                 'ITA00243': palette[5],
                 'ITA00248': palette[13],
                 'LUX00021': palette[6],
                 'NLD00013': palette[14],
                 'SWE00093': palette[7]}
    colors = [pop2color[p] for p in samples.Population]
    ax.bar(left, pc, color=colors)
    ax.set_xlim(0, len(pc))
    ax.set_xlabel('Sample index')
    ax.set_ylabel('Percent calls')
    ax.set_title(title)
    handles = [mpl.patches.Patch(color=palette[0]),
               mpl.patches.Patch(color=palette[8]),
               mpl.patches.Patch(color=palette[1]),
               mpl.patches.Patch(color=palette[9]),
               mpl.patches.Patch(color=palette[2]),
               mpl.patches.Patch(color=palette[10]),
               mpl.patches.Patch(color=palette[3]),
               mpl.patches.Patch(color=palette[11]),
               mpl.patches.Patch(color=palette[4]),
               mpl.patches.Patch(color=palette[12]),
               mpl.patches.Patch(color=palette[5]),
               mpl.patches.Patch(color=palette[13]),
               mpl.patches.Patch(color=palette[6]),
               mpl.patches.Patch(color=palette[14]),
               mpl.patches.Patch(color=palette[7])]
    ax.legend(handles=handles, labels=['ESP00102', 'ESP00199', 'ESP00337', 'FIN00015', 'FIN00020',
       'FIN00044', 'FIN00046', 'GBR00013', 'GBR00015', 'IRL00017',
       'ITA00243', 'ITA00248', 'LUX00021', 'NLD00013', 'SWE00093'], title='Population',
              bbox_to_anchor=(1, 1), loc='upper left')

# %% [markdown]
# ## Plot missing

# %%
plot_genotype_frequency(pc_missing, 'Missing')

# %% [markdown]
# ## Plot heterozygosity

# %%
plot_genotype_frequency(pc_het, 'Heterozygosity')

# %% [markdown]
# ## PCA

# %%
palette = sns.color_palette("hls",15)
pop_colours = {    
                'ESP00102': palette[0],
                 'ESP00199': palette[8],
                 'ESP00337': palette[1],
                 'FIN00015': palette[9],
                 'FIN00020': palette[2],
                 'FIN00044': palette[10],
                 'FIN00046': palette[3],
                 'GBR00013': palette[11],
                 'GBR00015': palette[4],
                 'IRL00017': palette[12],
                 'ITA00243': palette[5],
                 'ITA00248': palette[13],
                 'LUX00021': palette[6],
                 'NLD00013': palette[14],
                 'SWE00093': palette[7]
}

# %%
def plot_pca_coords(coords, model, pc1, pc2, ax, sample_population):
    sns.despine(ax=ax, offset=5)
    x = coords[:, pc1]
    y = coords[:, pc2]
    for pop in populations:
        flt = (sample_population == pop)
        ax.plot(x[flt], y[flt], marker='o', linestyle=' ', color=pop_colours[pop], 
                label=pop, markersize=6, mec='k', mew=.5)
    ax.set_xlabel('PC%s (%.1f%%)' % (pc1+1, model.explained_variance_ratio_[pc1]*100))
    ax.set_ylabel('PC%s (%.1f%%)' % (pc2+1, model.explained_variance_ratio_[pc2]*100))
    

def fig_pca(coords, model, title, sample_population=None):
    if sample_population is None:
        sample_population = samples.Population
    # plot coords for PCs 1 vs 2, 3 vs 4
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 2, 1)
    plot_pca_coords(coords, model, 0, 1, ax, sample_population)
    ax = fig.add_subplot(1, 2, 2)
    plot_pca_coords(coords, model, 2, 3, ax, sample_population)
    ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
    fig.suptitle(title, y=1.02)
    fig.tight_layout()

# %%
ac2 = gt_biallelic.count_alleles()
ac2
# Out:
# <AlleleCountsChunkedArray shape=(66279, 2) dtype=int32 chunks=(33140, 2)
#    nbytes=517.8K cbytes=165.1K cratio=3.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
flt = (ac2[:, :2].min(axis=1) > 1)
gf = gt_biallelic.compress(flt, axis=0)
gn = gf.to_n_alt()
gn
# Out:
# <ChunkedArrayWrapper shape=(48932, 351) dtype=int8 chunks=(1530, 351)
#    nbytes=16.4M cbytes=2.4M cratio=6.7
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
coords1, model1 = allel.pca(gn, n_components=10, scaler='patterson')

# %%
fig_pca(coords1, model1, 'Figure 1. Conventional PCA.')

# %%
outliers = ((coords1[:,0]>0) & (coords1[:,1]>0))
samples[outliers]
# Out:
#                ID Population
# 17   ESP00102-021   ESP00102
# 47   ESP00337-001   ESP00337
# 50   ESP00337-004   ESP00337
# 56   ESP00337-010   ESP00337
# 57   ESP00337-011   ESP00337
# ..            ...        ...
# 313  NLD00013-013   NLD00013
# 326  SWE00093-001   SWE00093
# 331  SWE00093-006   SWE00093
# 339  SWE00093-014   SWE00093
# 342  SWE00093-017   SWE00093
#
# [122 rows x 2 columns]

# %%
outliers = ((coords1[:,0]>0) & (coords1[:,1]>-60) &(coords1[:,1]<0))
samples[outliers]
# Out:
#                ID Population
# 48   ESP00337-002   ESP00337
# 49   ESP00337-003   ESP00337
# 51   ESP00337-005   ESP00337
# 52   ESP00337-006   ESP00337
# 53   ESP00337-007   ESP00337
# ..            ...        ...
# 345  SWE00093-020   SWE00093
# 346  SWE00093-021   SWE00093
# 348  SWE00093-023   SWE00093
# 349  SWE00093-024   SWE00093
# 350  SWE00093-025   SWE00093
#
# [131 rows x 2 columns]

# %%
outliers = ((coords1[:,0]>0) & (coords1[:,1]>-50) &(coords1[:,1]>50))
samples[outliers]
# Out:
#                ID Population
# 168  GBR00013-007   GBR00013
# 183  GBR00013-024   GBR00013
# 189  GBR00015-105   GBR00015
# 194  GBR00015-110   GBR00015
# 257  ITA00248-005   ITA00248
# 258  ITA00248-006   ITA00248
# 275  ITA00248-025   ITA00248
# 288  LUX00021-013   LUX00021
# 293  LUX00021-018   LUX00021

# %%
coords1[:,0]
# Out:
# array([-148.96736  , -197.95537  , -198.57387  , -201.8657   ,
#        -165.3257   , -184.72801  , -187.34471  , -189.30516  ,
#        -197.34256  , -215.09433  , -200.77628  , -134.40858  ,
#        -200.45107  , -196.02504  , -183.73141  , -193.42851  ,
#        -167.54001  , -184.20921  , -192.22644  , -177.55489  ,
#          46.86318  , -164.9474   , -195.9502   , -203.5213   ,
#        -209.70267  , -123.563416 , -141.0141   , -107.05087  ,
#        -125.844154 , -130.56828  , -208.34506  , -213.80334  ,
#        -151.85046  , -182.63112  , -189.61328  , -214.39732  ,
#        -192.13258  , -202.48477  , -181.60262  , -203.55826  ,
#        -172.12856  , -208.17152  , -188.02425  , -203.78363  ,
#        -180.83885  , -249.29147  , -183.55765  , -224.52124  ,
#        -133.97878  , -187.82428  ,   43.688126 ,   46.331024 ,
#          47.796894 ,   44.143612 ,   52.169872 ,   48.611168 ,
#          45.684795 ,   47.777916 ,   49.965984 ,   38.025356 ,
#          46.953    ,   43.407917 ,   44.516014 ,   48.488895 ,
#          41.447933 ,   44.572636 ,   46.966583 ,   48.531555 ,
#         106.74582  ,  111.11274  ,  105.04489  ,  105.97211  ,
#         102.34111  ,  111.556786 ,  110.79985  ,  106.66265  ,
#          99.22298  ,  113.14485  ,  103.79562  ,  103.29201  ,
#         111.36714  ,   93.97627  ,  103.06533  ,   95.74018  ,
#         107.49405  ,   99.55304  ,  106.86412  ,   92.72157  ,
#         110.527664 ,  107.33977  ,   53.039864 ,   42.458588 ,
#          44.447903 ,   43.431618 ,   41.593185 ,   38.288544 ,
#          57.771652 ,   45.52471  ,   51.033966 ,   51.325615 ,
#          48.70406  ,   46.670666 ,   48.43972  ,   49.949768 ,
#          55.008343 ,   42.150867 ,   47.681347 ,   53.956806 ,
#          54.58023  ,   54.86072  ,   50.398594 ,   57.59967  ,
#          38.226124 ,   45.793736 ,   47.949825 ,   51.67613  ,
#          51.249397 , -230.60321  ,   48.371605 ,   51.036724 ,
#          51.79164  ,   47.596714 ,   47.632294 ,   50.676323 ,
#          62.259674 ,   41.44569  ,   50.22225  ,   50.5978   ,
#          44.620533 ,   55.940292 ,   45.073162 ,   50.376102 ,
#          50.661274 ,   50.246586 ,   48.537693 ,   53.28232  ,
#          44.300163 ,   46.936882 ,   71.17535  ,   59.21394  ,
#          75.4884   ,   75.33378  ,   79.02474  , -207.37363  ,
#          56.48514  ,   55.785404 ,   79.510735 ,   79.994576 ,
#          64.03221  ,   58.58761  ,   53.855083 ,   82.98839  ,
#          73.97192  ,   77.82368  ,   74.73828  ,   61.375175 ,
#          83.45426  ,   56.903236 ,   62.08256  ,   73.39772  ,
#          54.36993  ,   79.72833  ,   59.893635 ,   48.91992  ,
#          75.00289  ,   73.3724   ,   54.79738  ,   78.76072  ,
#          55.27459  ,   75.02546  ,   55.775047 ,   56.98394  ,
#          54.659973 ,   51.3499   ,   53.98661  ,   58.08141  ,
#          53.229485 ,   59.85093  , -207.17319  ,   50.431282 ,
#          58.911575 ,   62.988914 ,   58.159256 ,   77.39617  ,
#        -118.51507  ,   72.81744  ,   76.92624  ,   56.6813   ],
#       dtype=float32)

# %%
coords1[:,0]<1000
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
allsamp = samples[coords1[:,0]<1000]
arr = np.concatenate((coords1, allsamp), axis=1)

# %%
import csv         
with open('/users/mcevoysu/scratch/output/Bpendula/scikit-allel/bpendula_pca_coords.txt', 'w') as f_output:
    tsv_output = csv.writer(f_output, delimiter='\t')
    for a in arr:
        tsv_output.writerow(a)
# Out:
#   Cell In[45], line 2
#     arr = np.concatenate((coords1, samples([coords1]), axis=1)
#                                                        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
pc_het[outliers]
# Out:
# array([7.41396979, 6.98092625])

# %%
pc_missing[outliers]
# Out:
# array([0.10247595, 0.10049255])

# %%
sample_het_pca = { "samples": samples_var, "het": pc_het, "PCA1": coords1[:,0], "PCA2": coords1[:,1], "PCA3": coords1[:,2], "PCA4": coords1[:,3] }
df=pandas.DataFrame(sample_het_pca)
df
df.to_csv("Bpendula_het_pca_by_sample.txt", sep='\t', index=False, header=True)
